# %% [markdown]
# ### Importando bibliotecas e lendo tabelas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
tabela_2021 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD21-01-05-2023.csv", sep=";", usecols=["DT_SIN_PRI","SG_UF_NOT","CS_SEXO",
                                                                                             "NU_IDADE_N", "CS_RACA", "NOSOCOMIAL",
                                                                                             "FATOR_RISC", "VACINA_COV", "HOSPITAL",
                                                                                             "CLASSI_FIN", "EVOLUCAO"])

# %%
tabela_2022 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD22-03-04-2023.csv", sep=";", usecols=["DT_SIN_PRI","SG_UF_NOT","CS_SEXO",
                                                                                             "NU_IDADE_N", "CS_RACA", "NOSOCOMIAL",
                                                                                             "FATOR_RISC", "VACINA_COV", "HOSPITAL",
                                                                                             "CLASSI_FIN", "EVOLUCAO"])

# %%
tabela_2023 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD23-15-04-2024.csv", sep=";")

# %%
tabela_2024 = pd.read_csv("C:\\Users\\amand\\Downloads\\2024.csv", sep=";")

# %%
tabela_2021
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        06/01/2021        BA       M          69        1         NaN
# 1        03/01/2021        BA       M          89        9         NaN
# 2        07/01/2021        PR       F          51        9        2.00
# 3        05/01/2021        PR       M          57        2        2.00
# 4        04/01/2021        RS       M          81        1        2.00
# ...             ...       ...     ...         ...      ...         ...
# 1048570  27/03/2021        BA       F          82        9        2.00
# 1048571  28/02/2021        RS       M          52        2        2.00
# 1048572  12/03/2021        MG       F          62        4        2.00
# 1048573  22/03/2021        MG       M          31        4        2.00
# 1048574  01/03/2021        RJ       F          80        9        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                 2      1.00        3.00      2.00         NaN
# 1                 2      1.00        5.00      2.00         NaN
# 2                 1      1.00        4.00      1.00         NaN
# 3                 1      1.00        4.00      3.00         NaN
# 4                 1      1.00        5.00      2.00         NaN
# ...             ...       ...         ...       ...         ...
# 1048570           2      1.00        5.00      9.00        9.00
# 1048571           1      1.00        5.00      2.00        9.00
# 1048572           1      1.00        5.00      2.00        2.00
# 1048573           2      1.00        5.00      2.00        2.00
# 1048574           1      1.00        5.00      1.00        1.00
#
# [1048575 rows x 11 columns]

# %%
tabela_2022
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       02/01/2022        RJ       M          23        4         NaN
# 1       03/01/2022        MS       F          37        4        2.00
# 2       04/01/2022        GO       F          33        4        2.00
# 3       04/01/2022        GO       M          76        4        1.00
# 4       06/01/2022        SP       F          16        1         NaN
# ...            ...       ...     ...         ...      ...         ...
# 557471  25/11/2022        PI       F          87        4        2.00
# 557472  25/06/2022        SC       M          27        1        2.00
# 557473  26/11/2022        PE       M          73        9         NaN
# 557474  26/07/2022        RO       F           1        4         NaN
# 557475  10/02/2022        SP       F          86        1        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                2      1.00        4.00      1.00        1.00
# 1                2      1.00        1.00      1.00        1.00
# 2                2      1.00        4.00      1.00        1.00
# 3                1      1.00        4.00      2.00        1.00
# 4                1      1.00        4.00      1.00        2.00
# ...            ...       ...         ...       ...         ...
# 557471           1      1.00        4.00      2.00        1.00
# 557472           2      1.00        4.00      1.00        2.00
# 557473           1      1.00         NaN       NaN        1.00
# 557474           2       NaN        4.00      1.00        2.00
# 557475           1      1.00        4.00      2.00        1.00
#
# [557476 rows x 11 columns]

# %%
tabela_2023
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        23/1/2023        RS       M          81     1.00        2.00
# 1        13/2/2023        SC       M          76     1.00        2.00
# 2        24/2/2023        RJ       M           8     4.00        2.00
# 3        26/2/2023        CE       M           1     4.00         NaN
# 4         4/2/2023        SP       F          18     1.00         NaN
# ...            ...       ...     ...         ...      ...         ...
# 278509  13/11/2023        BA       M          87     4.00         NaN
# 278510   1/12/2023        MG       F          91     1.00        1.00
# 278511  23/12/2023        GO       F           5     4.00        2.00
# 278512  27/12/2023        MG       M           1     1.00        2.00
# 278513    6/7/2023        PE       M           1     1.00        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0             1.00      1.00        5.00      3.00        1.00
# 1             1.00      1.00        4.00      1.00        1.00
# 2             1.00      1.00        2.00      1.00        1.00
# 3             2.00      1.00        4.00      1.00        1.00
# 4             2.00      1.00        5.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 278509        1.00      1.00        5.00      1.00        2.00
# 278510        1.00      1.00        5.00      1.00        1.00
# 278511        2.00      1.00        4.00      1.00        2.00
# 278512        1.00      1.00        4.00      1.00        2.00
# 278513        2.00      1.00         NaN       NaN        2.00
#
# [278514 rows x 11 columns]

# %%
tabela_2024
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        1/1/2024        CE       M          80        4        2.00
# 1        1/1/2024        PR       F          88        1        2.00
# 2      31/12/2023        PR       M          26        1        2.00
# 3        2/1/2024        CE       F          69        4        2.00
# 4        3/1/2024        PR       M           2        1        2.00
# ...           ...       ...     ...         ...      ...         ...
# 56117    7/4/2024        SP       M          63        4        9.00
# 56118   15/3/2024        CE       M           1        1        2.00
# 56119   19/3/2024        PR       F          76        1        2.00
# 56120    5/4/2024        PR       M          76        1        2.00
# 56121   12/4/2024        DF       F          70        1        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0               2      1.00         NaN       NaN        2.00
# 1               1      1.00        4.00      2.00        1.00
# 2               1      1.00        4.00      1.00        1.00
# 3               2      2.00        5.00       NaN        1.00
# 4               2      1.00        4.00      1.00        1.00
# ...           ...       ...         ...       ...         ...
# 56117           2      2.00         NaN       NaN        1.00
# 56118           2      1.00        1.00      1.00        2.00
# 56119           2      1.00        5.00      2.00        1.00
# 56120           1      1.00         NaN       NaN        2.00
# 56121           1      1.00        4.00       NaN        1.00
#
# [56122 rows x 11 columns]

# %%
tabela_2021.describe()
# Out:
#        NU_IDADE_N    CS_RACA  NOSOCOMIAL  FATOR_RISC   HOSPITAL  CLASSI_FIN  \
# count  1048575.00 1048575.00   864346.00  1048575.00 1020431.00  1000541.00
# mean        53.54       3.51        2.56        1.44       1.03        4.68
# std         22.36       2.83        1.94        0.50       0.37        0.63
# min         -9.00       1.00        1.00        1.00       1.00        1.00
# 25%         41.00       1.00        2.00        1.00       1.00        4.00
# 50%         56.00       4.00        2.00        1.00       1.00        5.00
# 75%         70.00       4.00        2.00        2.00       1.00        5.00
# max        150.00       9.00        9.00        2.00       9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 954533.00   779314.00
# mean       1.53        3.24
# std        1.34        3.11
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
sns.boxplot(data=tabela_2021, x="NU_IDADE_N");

# %%
tabela_2021=tabela_2021.loc[(tabela_2021['NU_IDADE_N'] >= 0) & (tabela_2021['NU_IDADE_N'] <= 100)]

# %%
tabela_2022.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   557476.00 557476.00   477693.00   557476.00 539571.00   524837.00
# mean        48.14      3.49        2.38        1.45      1.04        4.25
# std         32.58      2.82        1.68        0.50      0.37        0.93
# min         -9.00      1.00        1.00        1.00      1.00        1.00
# 25%          9.00      1.00        2.00        1.00      1.00        4.00
# 50%         58.00      4.00        2.00        1.00      1.00        4.00
# 75%         77.00      4.00        2.00        2.00      1.00        5.00
# max        136.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 502174.00   556568.00
# mean       1.47        1.59
# std        1.39        1.33
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
sns.boxplot(data=tabela_2022, x="NU_IDADE_N");

# %%
tabela_2022=tabela_2022.loc[(tabela_2022['NU_IDADE_N'] >= 0) & (tabela_2022['NU_IDADE_N'] <= 100)]

# %%
tabela_2023.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   278514.00 278513.00   245141.00   278513.00 270918.00   268860.00
# mean        32.35      3.39        2.26        1.55      1.03        3.66
# std         33.18      2.65        1.41        0.50      0.35        1.12
# min         -5.00      1.00        1.00        1.00      0.00        1.00
# 25%          3.00      1.00        2.00        1.00      1.00        4.00
# 50%         10.00      4.00        2.00        2.00      1.00        4.00
# 75%         67.00      4.00        2.00        2.00      1.00        4.00
# max        123.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 260308.00   278452.00
# mean       1.35        1.60
# std        1.27        1.10
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
sns.boxplot(data=tabela_2023, x="NU_IDADE_N");

# %%
tabela_2023=tabela_2023.loc[(tabela_2023['NU_IDADE_N'] >= 0) & (tabela_2023['NU_IDADE_N'] <= 100)]

# %%
tabela_2024.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    56122.00 56122.00    48901.00    56122.00  53858.00    46614.00
# mean        36.37     3.31        2.26        1.52      1.04        3.69
# std         33.74     2.57        1.46        0.50      0.42        1.25
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          4.00     1.00        2.00        1.00      1.00        3.00
# 50%         24.00     4.00        2.00        2.00      1.00        4.00
# 75%         71.00     4.00        2.00        2.00      1.00        5.00
# max        113.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  38624.00    56095.00
# mean       1.53        1.67
# std        1.64        1.27
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
sns.boxplot(data=tabela_2024, x="NU_IDADE_N");

# %%
tabela_2024=tabela_2024.loc[(tabela_2024['NU_IDADE_N'] >= 0) & (tabela_2024['NU_IDADE_N'] <= 100)]

# %%
tabela_2021.isnull().sum()
# Out:
# DT_SIN_PRI         0
# SG_UF_NOT          0
# CS_SEXO            0
# NU_IDADE_N         0
# CS_RACA            0
# NOSOCOMIAL    184050
# FATOR_RISC         0
# HOSPITAL       28107
# CLASSI_FIN     47991
# EVOLUCAO       93959
# VACINA_COV    269022
# dtype: int64

# %%
tabela_2022.isnull().sum()
# Out:
# DT_SIN_PRI        0
# SG_UF_NOT         0
# CS_SEXO           0
# NU_IDADE_N        0
# CS_RACA           0
# NOSOCOMIAL    79587
# FATOR_RISC        0
# HOSPITAL      17866
# CLASSI_FIN    32568
# EVOLUCAO      55189
# VACINA_COV      907
# dtype: int64

# %%
tabela_2023.isnull().sum()
# Out:
# DT_SIN_PRI        0
# SG_UF_NOT         0
# CS_SEXO           0
# NU_IDADE_N        0
# CS_RACA           1
# NOSOCOMIAL    33324
# FATOR_RISC        1
# HOSPITAL       7585
# CLASSI_FIN     9629
# EVOLUCAO      18169
# VACINA_COV       62
# dtype: int64

# %%
tabela_2024.isnull().sum()
# Out:
# DT_SIN_PRI        0
# SG_UF_NOT         0
# CS_SEXO           0
# NU_IDADE_N        0
# CS_RACA           0
# NOSOCOMIAL     7209
# FATOR_RISC        0
# HOSPITAL       2263
# CLASSI_FIN     9496
# EVOLUCAO      17477
# VACINA_COV       27
# dtype: int64

# %% [markdown]
# ### Descritivas (2021)

# %% [markdown]
# #### Análise Descritiva Sudeste (2021)

# %%
df_SE = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "ES")| (tabela_2021["SG_UF_NOT"] == "RJ") | (tabela_2021["SG_UF_NOT"] == "SP") | (tabela_2021["SG_UF_NOT"] == "MG")]

# %%
df_SE
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 5        04/01/2021        RJ       M          64        1        2.00
# 7        04/01/2021        RJ       F          63        1         NaN
# 8        04/01/2021        RJ       F           9        2         NaN
# 9        03/01/2021        SP       F          64        9        2.00
# 11       11/01/2021        SP       F          28        1         NaN
# ...             ...       ...     ...         ...      ...         ...
# 1048565  21/03/2021        SP       F          56        4        9.00
# 1048567  15/03/2021        MG       F          79        4        2.00
# 1048572  12/03/2021        MG       F          62        4        2.00
# 1048573  22/03/2021        MG       M          31        4        2.00
# 1048574  01/03/2021        RJ       F          80        9        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 5                 1      1.00        5.00      1.00         NaN
# 7                 2      1.00        5.00       NaN         NaN
# 8                 2      1.00        4.00      1.00         NaN
# 9                 1      1.00        5.00      9.00         NaN
# 11                2      1.00        5.00      1.00         NaN
# ...             ...       ...         ...       ...         ...
# 1048565           2      1.00        5.00      1.00        2.00
# 1048567           2      1.00        5.00      9.00        1.00
# 1048572           1      1.00        5.00      2.00        2.00
# 1048573           2      1.00        5.00      2.00        2.00
# 1048574           1      1.00        5.00      1.00        1.00
#
# [519466 rows x 11 columns]

# %%
df_SE.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   519466.00 519466.00   437478.00   519466.00 509352.00   502375.00
# mean        53.97      3.34        2.70        1.43      1.03        4.66
# std         22.54      2.91        2.13        0.50      0.38        0.64
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%         41.00      1.00        2.00        1.00      1.00        4.00
# 50%         57.00      2.00        2.00        1.00      1.00        5.00
# 75%         70.00      4.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 483397.00   400916.00
# mean       1.46        3.14
# std        1.21        3.06
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
df_SE["CS_SEXO"].value_counts()
# Out:
# M    281669
# F    237732
# I        65
# Name: CS_SEXO, dtype: int64

# %%
df_SE["CS_RACA"].value_counts()
# Out:
# 1    246337
# 4    148102
# 9     91398
# 2     28402
# 3      4913
# 5       314
# Name: CS_RACA, dtype: int64

# %%
df_SE["CLASSI_FIN"].value_counts()
# Out:
# 5.00    360210
# 4.00    130026
# 2.00      5186
# 1.00      5110
# 3.00      1843
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE["EVOLUCAO"].value_counts()
# Out:
# 1.00    335992
# 2.00    131423
# 9.00     10188
# 3.00      5794
# Name: EVOLUCAO, dtype: int64

# %%
df_SE["VACINA_COV"].value_counts()
# Out:
# 2.00    180659
# 1.00    135617
# 9.00     84640
# Name: VACINA_COV, dtype: int64

# %%
df_SE["HOSPITAL"].value_counts()
# Out:
# 1.00    499058
# 2.00      9251
# 9.00      1043
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2021');

# %%
sns.countplot(data=df_SE, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2021");

# %% [markdown]
# 1 = sim, 2 = não, 9 = ignorado

# %% [markdown]
# #### Análise Descritiva Sul(2021)

# %%
df_S = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "SC")| (tabela_2021["SG_UF_NOT"] == "RS") | (tabela_2021["SG_UF_NOT"] == "PR")]

# %%
df_S
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 2        07/01/2021        PR       F          51        9        2.00
# 3        05/01/2021        PR       M          57        2        2.00
# 4        04/01/2021        RS       M          81        1        2.00
# 10       04/01/2021        PR       F          26        1        2.00
# 14       07/01/2021        SC       F           3        1         NaN
# ...             ...       ...     ...         ...      ...         ...
# 1048550  13/05/2021        PR       M          66        4        2.00
# 1048552  08/05/2021        PR       F          34        1        2.00
# 1048557  30/04/2021        SC       F          29        1        2.00
# 1048566  04/02/2021        PR       F          45        1        2.00
# 1048571  28/02/2021        RS       M          52        2        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 2                 1      1.00        4.00      1.00         NaN
# 3                 1      1.00        4.00      3.00         NaN
# 4                 1      1.00        5.00      2.00         NaN
# 10                1      1.00        4.00      1.00        2.00
# 14                1      1.00        4.00      1.00        2.00
# ...             ...       ...         ...       ...         ...
# 1048550           1      1.00        5.00      2.00        1.00
# 1048552           2      1.00        5.00       NaN        2.00
# 1048557           2      1.00        5.00      1.00        2.00
# 1048566           2      1.00        5.00      1.00        2.00
# 1048571           1      1.00        5.00      2.00        9.00
#
# [184851 rows x 11 columns]

# %%
df_S.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   184851.00 184851.00   162244.00   184851.00 183588.00   182047.00
# mean        54.10      2.13        2.20        1.39      1.01        4.71
# std         21.36      2.53        1.24        0.49      0.21        0.61
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%         42.00      1.00        2.00        1.00      1.00        5.00
# 50%         56.00      1.00        2.00        1.00      1.00        5.00
# 75%         70.00      1.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 173464.00   141970.00
# mean       1.47        2.88
# std        1.21        2.83
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
df_S["CS_SEXO"].value_counts()
# Out:
# M    101661
# F     83179
# I        11
# Name: CS_SEXO, dtype: int64

# %%
df_S["CS_RACA"].value_counts()
# Out:
# 1    145328
# 9     20167
# 4     13102
# 2      5020
# 3      1001
# 5       233
# Name: CS_RACA, dtype: int64

# %%
df_S["CLASSI_FIN"].value_counts()
# Out:
# 5.00    138931
# 4.00     38354
# 2.00      4097
# 1.00       342
# 3.00       323
# Name: CLASSI_FIN, dtype: int64

# %%
df_S["EVOLUCAO"].value_counts()
# Out:
# 1.00    120383
# 2.00     46174
# 9.00      3639
# 3.00      3268
# Name: EVOLUCAO, dtype: int64

# %%
df_S["VACINA_COV"].value_counts()
# Out:
# 2.00    71172
# 1.00    46306
# 9.00    24492
# Name: VACINA_COV, dtype: int64

# %%
df_S["HOSPITAL"].value_counts()
# Out:
# 1.00    181632
# 2.00      1863
# 9.00        93
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S, x="NU_IDADE_N", color="red").set(title='Idade sul 2021');

# %%
sns.countplot(data=df_S, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2021");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2021)

# %%
df_CO = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "MS")| (tabela_2021["SG_UF_NOT"] == "MT") | (tabela_2021["SG_UF_NOT"] == "GO") | (tabela_2021["SG_UF_NOT"] == "DF")]

# %%
df_CO
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 12       07/01/2021        DF       M           2        4        2.00
# 16       08/01/2021        MS       M          84        1        9.00
# 44       06/01/2021        DF       M          62        9        9.00
# 51       03/01/2021        DF       F          19        9        2.00
# 60       05/01/2021        MT       F          44        4        2.00
# ...             ...       ...     ...         ...      ...         ...
# 1048517  09/03/2021        MS       F          43        1         NaN
# 1048534  06/01/2021        DF       M          45        9        2.00
# 1048538  05/06/2021        DF       M          58        1        2.00
# 1048560  04/03/2021        DF       M          40        9        2.00
# 1048569  14/03/2021        DF       F          56        9        9.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 12                2      1.00        4.00      1.00         NaN
# 16                1      1.00        5.00      2.00         NaN
# 44                1      1.00        4.00      1.00         NaN
# 51                1      1.00        4.00      1.00         NaN
# 60                1      1.00        4.00      1.00         NaN
# ...             ...       ...         ...       ...         ...
# 1048517           1      1.00        5.00      2.00         NaN
# 1048534           1      1.00        5.00      1.00         NaN
# 1048538           1      1.00        5.00      1.00        1.00
# 1048560           2      1.00        5.00      2.00        9.00
# 1048569           1      1.00        5.00      1.00        1.00
#
# [92709 rows x 11 columns]

# %%
df_CO.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    92709.00 92709.00    79053.00    92709.00  90222.00    91901.00
# mean        52.23     4.35        2.52        1.48      1.03        4.76
# std         20.94     2.79        1.88        0.50      0.35        0.61
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%         40.00     2.00        2.00        1.00      1.00        5.00
# 50%         54.00     4.00        2.00        1.00      1.00        5.00
# 75%         67.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  89966.00    71036.00
# mean       1.37        3.26
# std        0.89        3.08
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
df_CO["CS_SEXO"].value_counts()
# Out:
# M    51347
# F    41361
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_CO["CS_RACA"].value_counts()
# Out:
# 4    45516
# 1    21789
# 9    20892
# 2     2980
# 3     1179
# 5      353
# Name: CS_RACA, dtype: int64

# %%
df_CO["CLASSI_FIN"].value_counts()
# Out:
# 5.00    74654
# 4.00    14893
# 2.00     1680
# 1.00      574
# 3.00      100
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO["EVOLUCAO"].value_counts()
# Out:
# 1.00    64107
# 2.00    24024
# 3.00      965
# 9.00      870
# Name: EVOLUCAO, dtype: int64

# %%
df_CO["VACINA_COV"].value_counts()
# Out:
# 2.00    35575
# 1.00    19826
# 9.00    15635
# Name: VACINA_COV, dtype: int64

# %%
df_CO["HOSPITAL"].value_counts()
# Out:
# 1.00    88731
# 2.00     1343
# 9.00      148
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2021');

# %%
sns.countplot(data=df_CO, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2021");

# %% [markdown]
# #### Analise descritiva Norte (2021)

# %%
df_N = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "TO")| (tabela_2021["SG_UF_NOT"] == "PA") | (tabela_2021["SG_UF_NOT"] == "AP")  | (tabela_2021["SG_UF_NOT"] == "RR") | (tabela_2021["SG_UF_NOT"] == "AM") | (tabela_2021["SG_UF_NOT"] == "AC") | (tabela_2021["SG_UF_NOT"] == "RO")]

# %%
df_N
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 20       09/01/2021        AM       F           2        4        2.00
# 32       03/01/2021        PA       M          83        4         NaN
# 62       05/01/2021        TO       M          69        4        2.00
# 92       05/01/2021        PA       F          77        4        2.00
# 93       10/01/2021        TO       F          26        4        1.00
# ...             ...       ...     ...         ...      ...         ...
# 1048526  24/02/2021        AC       F          86        3         NaN
# 1048535  11/03/2021        PA       F          49        1        2.00
# 1048541  25/03/2021        TO       M          89        4        2.00
# 1048544  01/05/2021        AC       M          69        4        2.00
# 1048555  05/04/2021        TO       M          72        4        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 20                1      1.00        5.00      1.00         NaN
# 32                2      1.00         NaN       NaN         NaN
# 62                1      1.00        4.00       NaN         NaN
# 92                1      1.00        5.00      1.00        1.00
# 93                2      1.00        4.00      1.00         NaN
# ...             ...       ...         ...       ...         ...
# 1048526           2      1.00        5.00      2.00         NaN
# 1048535           1      1.00        5.00      2.00        2.00
# 1048541           1      1.00        5.00      2.00        2.00
# 1048544           1      1.00        5.00      2.00        9.00
# 1048555           1      1.00        5.00      1.00         NaN
#
# [62667 rows x 11 columns]

# %%
df_N.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    62667.00 62667.00    49833.00    62667.00  58654.00    58011.00
# mean        52.18     3.90        2.27        1.57      1.05        4.75
# std         21.46     1.51        1.43        0.50      0.42        0.55
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%         39.00     4.00        2.00        1.00      1.00        5.00
# 50%         54.00     4.00        2.00        2.00      1.00        5.00
# 75%         68.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  54351.00    40532.00
# mean       1.65        3.57
# std        1.54        3.19
# min        1.00        1.00
# 25%        1.00        2.00
# 50%        1.00        2.00
# 75%        2.00        9.00
# max        9.00        9.00

# %%
df_N["CS_SEXO"].value_counts()
# Out:
# M    34526
# F    28120
# I       21
# Name: CS_SEXO, dtype: int64

# %%
df_N["CS_RACA"].value_counts()
# Out:
# 4    50360
# 1     6037
# 9     3186
# 2     1886
# 3      617
# 5      581
# Name: CS_RACA, dtype: int64

# %%
df_N["CLASSI_FIN"].value_counts()
# Out:
# 5.00    45287
# 4.00    11809
# 2.00      381
# 1.00      328
# 3.00      206
# Name: CLASSI_FIN, dtype: int64

# %%
df_N["EVOLUCAO"].value_counts()
# Out:
# 1.00    34091
# 2.00    17346
# 9.00     2044
# 3.00      870
# Name: EVOLUCAO, dtype: int64

# %%
df_N["VACINA_COV"].value_counts()
# Out:
# 2.00    21982
# 9.00    10271
# 1.00     8279
# Name: VACINA_COV, dtype: int64

# %%
df_N["HOSPITAL"].value_counts()
# Out:
# 1.00    56729
# 2.00     1792
# 9.00      133
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N, x="NU_IDADE_N", color="blue").set(title='Idade norte 2021');

# %%
sns.countplot(data=df_N, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2021");

# %% [markdown]
# #### Analise descritiva Nordeste (2021)

# %%
df_NE = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "AL")| (tabela_2021["SG_UF_NOT"] == "BA") | (tabela_2021["SG_UF_NOT"] == "CE") | (tabela_2021["SG_UF_NOT"] == "MA") | (tabela_2021["SG_UF_NOT"] == "PB") | (tabela_2021["SG_UF_NOT"] == "PE") | (tabela_2021["SG_UF_NOT"] == "PI") | (tabela_2021["SG_UF_NOT"] == "RN") | (tabela_2021["SG_UF_NOT"] == "SE")]

# %%
df_NE
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        06/01/2021        BA       M          69        1         NaN
# 1        03/01/2021        BA       M          89        9         NaN
# 6        06/01/2021        CE       F          89        4        2.00
# 15       04/01/2021        PB       F           1        1        2.00
# 25       04/01/2021        SE       F          70        1        2.00
# ...             ...       ...     ...         ...      ...         ...
# 1048547  11/05/2021        RN       M          18        4        2.00
# 1048553  14/05/2021        BA       M          38        9        2.00
# 1048564  16/03/2021        PI       M          79        4        2.00
# 1048568  19/03/2021        BA       M          53        4        2.00
# 1048570  27/03/2021        BA       F          82        9        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                 2      1.00        3.00      2.00         NaN
# 1                 2      1.00        5.00      2.00         NaN
# 6                 1      1.00        5.00      1.00        1.00
# 15                2      1.00        5.00      1.00         NaN
# 25                1      1.00        5.00      9.00         NaN
# ...             ...       ...         ...       ...         ...
# 1048547           1      1.00        5.00      1.00        2.00
# 1048553           1      1.00        5.00      1.00        9.00
# 1048564           1      1.00        5.00       NaN         NaN
# 1048568           2      1.00        4.00      1.00        9.00
# 1048570           2      1.00        5.00      9.00        9.00
#
# [187938 rows x 11 columns]

# %%
df_NE.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   187938.00 187938.00   134973.00   187938.00 177708.00   165306.00
# mean        52.64      4.81        2.68        1.46      1.05        4.64
# std         23.46      2.54        2.12        0.50      0.44        0.64
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%         39.00      4.00        2.00        1.00      1.00        4.00
# 50%         55.00      4.00        2.00        1.00      1.00        5.00
# 75%         70.00      4.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 152494.00   124155.00
# mean       1.83        3.88
# std        1.89        3.44
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        9.00
# max        9.00        9.00

# %%
df_NE["CS_SEXO"].value_counts()
# Out:
# M    101736
# F     86128
# I        74
# Name: CS_SEXO, dtype: int64

# %%
df_NE["CS_RACA"].value_counts()
# Out:
# 4    114760
# 9     44992
# 1     19792
# 2      6307
# 3      1834
# 5       253
# Name: CS_RACA, dtype: int64

# %%
df_NE["CLASSI_FIN"].value_counts()
# Out:
# 5.00    115024
# 4.00     46573
# 1.00      1921
# 2.00       899
# 3.00       889
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE["EVOLUCAO"].value_counts()
# Out:
# 1.00    94137
# 2.00    46444
# 9.00     9260
# 3.00     2653
# Name: EVOLUCAO, dtype: int64

# %%
df_NE["VACINA_COV"].value_counts()
# Out:
# 2.00    51931
# 9.00    38216
# 1.00    34008
# Name: VACINA_COV, dtype: int64

# %%
df_NE["HOSPITAL"].value_counts()
# Out:
# 1.00    172575
# 2.00      4671
# 9.00       462
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2021');

# %%
sns.countplot(data=df_NE, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2021");

# %% [markdown]
# ### Descritivas (2022)

# %% [markdown]
# #### Analise descritiva Sudeste (2022)

# %%
df_SE22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "ES")| (tabela_2022["SG_UF_NOT"] == "RJ") | (tabela_2022["SG_UF_NOT"] == "SP") | (tabela_2022["SG_UF_NOT"] == "MG")]

# %%
df_SE22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       02/01/2022        RJ       M          23        4         NaN
# 4       06/01/2022        SP       F          16        1         NaN
# 7       08/01/2022        SP       M          55        9         NaN
# 10      07/01/2022        SP       M           1        1         NaN
# 11      06/01/2022        MG       F          50        4        2.00
# ...            ...       ...     ...         ...      ...         ...
# 557462  27/11/2022        RJ       M           4        4        2.00
# 557465  13/12/2022        SP       M           2        4        2.00
# 557466  03/12/2022        SP       M          52        1        2.00
# 557468  23/12/2022        SP       F          62        1        2.00
# 557475  10/02/2022        SP       F          86        1        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                2      1.00        4.00      1.00        1.00
# 4                1      1.00        4.00      1.00        2.00
# 7                2      1.00        5.00      1.00        9.00
# 10               2      1.00        4.00      1.00        2.00
# 11               1      1.00        4.00      1.00        2.00
# ...            ...       ...         ...       ...         ...
# 557462           2      1.00        4.00       NaN        2.00
# 557465           2      1.00        4.00      1.00        2.00
# 557466           1      1.00        5.00      1.00        1.00
# 557468           2      1.00        5.00      9.00        1.00
# 557475           1      1.00        4.00      2.00        1.00
#
# [273047 rows x 11 columns]

# %%
df_SE22.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   273047.00 273047.00   235938.00   273047.00 268513.00   264247.00
# mean        49.74      3.38        2.51        1.43      1.03        4.31
# std         32.59      2.94        1.89        0.49      0.40        0.85
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%          9.00      1.00        2.00        1.00      1.00        4.00
# 50%         60.00      2.00        2.00        1.00      1.00        4.00
# 75%         78.00      4.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 251325.00   272987.00
# mean       1.46        1.54
# std        1.38        1.29
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_SE22["CS_SEXO"].value_counts()
# Out:
# M    137452
# F    135577
# I        18
# Name: CS_SEXO, dtype: int64

# %%
df_SE22["CS_RACA"].value_counts()
# Out:
# 1    130120
# 4     77907
# 9     49710
# 2     12361
# 3      2738
# 5       211
# Name: CS_RACA, dtype: int64

# %%
df_SE22["CLASSI_FIN"].value_counts()
# Out:
# 4.00    123149
# 5.00    122639
# 2.00     11648
# 1.00      5080
# 3.00      1731
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE22["EVOLUCAO"].value_counts()
# Out:
# 1.00    192359
# 2.00     46324
# 9.00      7223
# 3.00      5419
# Name: EVOLUCAO, dtype: int64

# %%
df_SE22["VACINA_COV"].value_counts()
# Out:
# 1.00    172561
# 2.00     93528
# 9.00      6898
# Name: VACINA_COV, dtype: int64

# %%
df_SE22["HOSPITAL"].value_counts()
# Out:
# 1.00    263475
# 2.00      4432
# 9.00       606
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE22, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2022');

# %%
sns.countplot(data=df_SE22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2022");

# %% [markdown]
# #### Análise Descritiva Sul(2022)

# %%
df_S22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "SC")| (tabela_2022["SG_UF_NOT"] == "RS") | (tabela_2022["SG_UF_NOT"] == "PR")]

# %%
df_S22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 6       02/01/2022        SC       M          75        1        2.00
# 9       02/01/2022        RS       M          55        1         NaN
# 13      06/01/2022        PR       M          69        1        2.00
# 22      10/01/2022        SC       M           2        1        2.00
# 23      13/01/2022        SC       F          94        1        2.00
# ...            ...       ...     ...         ...      ...         ...
# 557464  17/12/2022        PR       F           2        1        2.00
# 557467  18/12/2022        PR       F          70        1        2.00
# 557469  12/12/2022        RS       F          72        9         NaN
# 557470  10/11/2022        PR       F          69        1        2.00
# 557472  25/06/2022        SC       M          27        1        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 6                1      1.00        5.00      2.00        1.00
# 9                1      1.00        5.00      1.00        1.00
# 13               1      1.00        1.00      1.00        1.00
# 22               2      1.00        5.00      1.00        2.00
# 23               1      1.00        4.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 557464           2      1.00        2.00      1.00        2.00
# 557467           2      1.00        5.00      1.00        1.00
# 557469           1      1.00        5.00      2.00        1.00
# 557470           1      1.00        4.00      1.00        1.00
# 557472           2      1.00        4.00      1.00        2.00
#
# [109353 rows x 11 columns]

# %%
df_S22.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   109353.00 109353.00   101446.00   109353.00 108329.00   108365.00
# mean        48.61      2.20        2.10        1.40      1.02        4.10
# std         32.00      2.59        1.00        0.49      0.17        1.07
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%         10.00      1.00        2.00        1.00      1.00        4.00
# 50%         59.00      1.00        2.00        1.00      1.00        4.00
# 75%         76.00      1.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 106224.00   109339.00
# mean       1.35        1.48
# std        1.12        1.11
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_S22.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   109353.00 109353.00   101446.00   109353.00 108329.00   108365.00
# mean        48.61      2.20        2.10        1.40      1.02        4.10
# std         32.00      2.59        1.00        0.49      0.17        1.07
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%         10.00      1.00        2.00        1.00      1.00        4.00
# 50%         59.00      1.00        2.00        1.00      1.00        4.00
# 75%         76.00      1.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 106224.00   109339.00
# mean       1.35        1.48
# std        1.12        1.11
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_S22["CS_SEXO"].value_counts()
# Out:
# M    55103
# F    54248
# I        2
# Name: CS_SEXO, dtype: int64

# %%
df_S22["CS_RACA"].value_counts()
# Out:
# 1    84353
# 9    12551
# 4     8614
# 2     3015
# 3      582
# 5      238
# Name: CS_RACA, dtype: int64

# %%
df_S22["CLASSI_FIN"].value_counts()
# Out:
# 4.00    47000
# 5.00    45595
# 2.00    11973
# 1.00     3404
# 3.00      393
# Name: CLASSI_FIN, dtype: int64

# %%
df_S22["EVOLUCAO"].value_counts()
# Out:
# 1.00    85026
# 2.00    15982
# 3.00     3386
# 9.00     1830
# Name: EVOLUCAO, dtype: int64

# %%
df_S22["VACINA_COV"].value_counts()
# Out:
# 1.00    69945
# 2.00    37496
# 9.00     1898
# Name: VACINA_COV, dtype: int64

# %%
df_S22["HOSPITAL"].value_counts()
# Out:
# 1.00    106828
# 2.00      1474
# 9.00        27
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S22, x="NU_IDADE_N", color="red").set(title='Idade sul 2022');

# %%
sns.countplot(data=df_S22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2022");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2022)

# %%
df_CO22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "MS")| (tabela_2022["SG_UF_NOT"] == "MT") | (tabela_2022["SG_UF_NOT"] == "GO") | (tabela_2022["SG_UF_NOT"] == "DF")]

# %%
df_CO22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 1       03/01/2022        MS       F          37        4        2.00
# 2       04/01/2022        GO       F          33        4        2.00
# 3       04/01/2022        GO       M          76        4        1.00
# 5       02/01/2022        MT       M          21        4        2.00
# 12      06/01/2022        MS       M           1        1        2.00
# ...            ...       ...     ...         ...      ...         ...
# 557401  27/10/2022        MS       M          72        4        2.00
# 557410  15/12/2022        DF       F          64        5        2.00
# 557440  15/12/2022        MS       M          24        4        2.00
# 557450  18/12/2022        GO       M          93        9        2.00
# 557459  11/12/2022        MS       M          10        4        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 1                2      1.00        1.00      1.00        1.00
# 2                2      1.00        4.00      1.00        1.00
# 3                1      1.00        4.00      2.00        1.00
# 5                2      1.00        4.00      1.00        2.00
# 12               2      1.00        4.00      1.00        2.00
# ...            ...       ...         ...       ...         ...
# 557401           1      1.00        4.00      1.00        1.00
# 557410           1      1.00        4.00      2.00        1.00
# 557440           1      1.00        4.00      1.00        1.00
# 557450           1      1.00        5.00      1.00        1.00
# 557459           1      1.00        4.00      1.00        2.00
#
# [45285 rows x 11 columns]

# %%
df_CO22.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    45285.00 45285.00    41998.00    45285.00  45016.00    44763.00
# mean        44.92     4.26        2.34        1.45      1.02        4.17
# std         32.49     2.65        1.60        0.50      0.23        1.08
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          7.00     2.00        2.00        1.00      1.00        4.00
# 50%         53.00     4.00        2.00        1.00      1.00        4.00
# 75%         75.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  43875.00    45278.00
# mean       1.25        1.60
# std        0.70        1.22
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_CO22["CS_SEXO"].value_counts()
# Out:
# M    23439
# F    21846
# Name: CS_SEXO, dtype: int64

# %%
df_CO22["CS_RACA"].value_counts()
# Out:
# 4    24124
# 1    10265
# 9     8972
# 2     1165
# 3      437
# 5      322
# Name: CS_RACA, dtype: int64

# %%
df_CO22["CLASSI_FIN"].value_counts()
# Out:
# 5.00    21292
# 4.00    17343
# 2.00     4265
# 1.00     1609
# 3.00      254
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO22["EVOLUCAO"].value_counts()
# Out:
# 1.00    35530
# 2.00     6944
# 3.00     1203
# 9.00      198
# Name: EVOLUCAO, dtype: int64

# %%
df_CO22["VACINA_COV"].value_counts()
# Out:
# 1.00    25081
# 2.00    19186
# 9.00     1011
# Name: VACINA_COV, dtype: int64

# %%
df_CO22["HOSPITAL"].value_counts()
# Out:
# 1.00    44289
# 2.00      699
# 9.00       28
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO22, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2022');

# %%
sns.countplot(data=df_CO22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2022");

# %% [markdown]
# #### Analise descritiva Norte (2022)

# %%
df_N22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "TO")| (tabela_2022["SG_UF_NOT"] == "PA") | (tabela_2022["SG_UF_NOT"] == "AP")  | (tabela_2022["SG_UF_NOT"] == "RR") | (tabela_2022["SG_UF_NOT"] == "AM") | (tabela_2022["SG_UF_NOT"] == "AC") | (tabela_2022["SG_UF_NOT"] == "RO")]

# %%
df_N22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 18      10/01/2022        RO       M          69        1        2.00
# 26      05/01/2022        PA       M          60        4        2.00
# 34      07/01/2022        TO       M          77        2        2.00
# 41      19/01/2022        AC       M          51        4        2.00
# 48      18/01/2022        PA       M          56        4        9.00
# ...            ...       ...     ...         ...      ...         ...
# 557414  19/12/2022        PA       F          78        4        2.00
# 557425  10/07/2022        RO       F           2        4         NaN
# 557426  02/01/2022        RO       F          86        4        2.00
# 557448  19/02/2022        PA       M           8        4        2.00
# 557474  26/07/2022        RO       F           1        4         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 18               1      1.00        4.00      1.00        1.00
# 26               1      1.00        5.00      1.00        1.00
# 34               1      1.00        5.00       NaN        1.00
# 41               1      1.00        5.00      2.00        1.00
# 48               1      1.00        4.00      3.00        2.00
# ...            ...       ...         ...       ...         ...
# 557414           1      1.00        4.00       NaN        1.00
# 557425           2       NaN        4.00      1.00        2.00
# 557426           2      1.00        4.00      1.00        1.00
# 557448           2      1.00        5.00      1.00        2.00
# 557474           2       NaN        4.00      1.00        2.00
#
# [24208 rows x 11 columns]

# %%
df_N22.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    24208.00 24208.00    20591.00    24208.00  22577.00    22691.00
# mean        44.12     3.95        2.13        1.56      1.06        4.33
# std         31.14     1.40        1.18        0.50      0.43        0.84
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          9.00     4.00        2.00        1.00      1.00        4.00
# 50%         49.00     4.00        2.00        2.00      1.00        4.00
# 75%         72.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  20964.00    24197.00
# mean       1.52        1.71
# std        1.43        1.39
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
df_N22["CS_SEXO"].value_counts()
# Out:
# M    12792
# F    11412
# I        4
# Name: CS_SEXO, dtype: int64

# %%
df_N22["CS_RACA"].value_counts()
# Out:
# 4    19942
# 1     1984
# 9     1083
# 2      540
# 5      477
# 3      182
# Name: CS_RACA, dtype: int64

# %%
df_N22["CLASSI_FIN"].value_counts()
# Out:
# 5.00    11044
# 4.00     9854
# 2.00     1157
# 3.00      345
# 1.00      291
# Name: CLASSI_FIN, dtype: int64

# %%
df_N22["EVOLUCAO"].value_counts()
# Out:
# 1.00    15427
# 2.00     3986
# 3.00      910
# 9.00      641
# Name: EVOLUCAO, dtype: int64

# %%
df_N22["VACINA_COV"].value_counts()
# Out:
# 1.00    12241
# 2.00    11211
# 9.00      745
# Name: VACINA_COV, dtype: int64

# %%
df_N22["HOSPITAL"].value_counts()
# Out:
# 1.00    21627
# 2.00      897
# 9.00       53
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N22, x="NU_IDADE_N", color="blue").set(title='Idade norte 2022');

# %%
sns.countplot(data=df_N22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2022");

# %% [markdown]
# #### Análise Descritiva Nordeste (2022)

# %%
df_NE22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "AL")| (tabela_2022["SG_UF_NOT"] == "BA") | (tabela_2022["SG_UF_NOT"] == "CE") | (tabela_2022["SG_UF_NOT"] == "MA") | (tabela_2022["SG_UF_NOT"] == "PB") | (tabela_2022["SG_UF_NOT"] == "PE") | (tabela_2022["SG_UF_NOT"] == "PI") | (tabela_2022["SG_UF_NOT"] == "RN") | (tabela_2022["SG_UF_NOT"] == "SE")]

# %%
df_NE22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 8       06/01/2022        BA       M          83        9        9.00
# 15      08/01/2022        PB       M           2        4        2.00
# 24      16/01/2022        CE       F          47        1        2.00
# 29      12/01/2022        RN       M          79        4        2.00
# 31      17/01/2022        CE       F          49        4        9.00
# ...            ...       ...     ...         ...      ...         ...
# 557457  20/11/2022        BA       M          61        2        9.00
# 557458  17/11/2022        SE       F           1        9        2.00
# 557461  19/11/2022        PE       F          91        9         NaN
# 557471  25/11/2022        PI       F          87        4        2.00
# 557473  26/11/2022        PE       M          73        9         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 8                2      1.00        4.00      2.00        1.00
# 15               2      1.00        4.00      1.00        2.00
# 24               2       NaN         NaN       NaN        2.00
# 29               1      1.00        4.00      1.00        1.00
# 31               2      1.00        5.00      3.00        1.00
# ...            ...       ...         ...       ...         ...
# 557457           1      1.00        5.00       NaN        2.00
# 557458           2      1.00        4.00      1.00        2.00
# 557461           2      1.00        5.00      1.00        1.00
# 557471           1      1.00        4.00      2.00        1.00
# 557473           1      1.00         NaN       NaN        1.00
#
# [104394 rows x 11 columns]

# %%
df_NE22.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   104394.00 104394.00    76727.00   104394.00  93986.00    83653.00
# mean        45.16      4.70        2.44        1.53      1.07        4.26
# std         32.82      2.40        1.81        0.50      0.46        0.87
# min          0.00      1.00        1.00        1.00      1.00        1.00
# 25%          7.00      4.00        2.00        1.00      1.00        4.00
# 50%         52.00      4.00        2.00        2.00      1.00        4.00
# 75%         75.00      4.00        2.00        2.00      1.00        5.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  78710.00   103579.00
# mean       1.76        1.77
# std        1.90        1.62
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
df_NE22["CS_SEXO"].value_counts()
# Out:
# M    52819
# F    51518
# I       57
# Name: CS_SEXO, dtype: int64

# %%
df_NE22["CS_RACA"].value_counts()
# Out:
# 4    68085
# 9    21991
# 1    10047
# 2     3170
# 3      921
# 5      180
# Name: CS_RACA, dtype: int64

# %%
df_NE22["CLASSI_FIN"].value_counts()
# Out:
# 4.00    41195
# 5.00    35617
# 2.00     3337
# 1.00     1978
# 3.00     1526
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE22["EVOLUCAO"].value_counts()
# Out:
# 1.00    54531
# 2.00    16531
# 9.00     4694
# 3.00     2954
# Name: EVOLUCAO, dtype: int64

# %%
df_NE22["VACINA_COV"].value_counts()
# Out:
# 1.00    55872
# 2.00    43190
# 9.00     4517
# Name: VACINA_COV, dtype: int64

# %%
df_NE22["HOSPITAL"].value_counts()
# Out:
# 1.00    89557
# 2.00     4181
# 9.00      248
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE22, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2022');

# %%
sns.countplot(data=df_NE22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2022");

# %% [markdown]
# ### Descritivas (2023)

# %% [markdown]
# #### Análise Descritiva Sudeste (2023)

# %%
df_SE23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "ES")| (tabela_2023["SG_UF_NOT"] == "RJ") | (tabela_2023["SG_UF_NOT"] == "SP") | (tabela_2023["SG_UF_NOT"] == "MG")]

# %%
df_SE23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 2        24/2/2023        RJ       M           8     4.00        2.00
# 4         4/2/2023        SP       F          18     1.00         NaN
# 6        16/2/2023        SP       F          20     4.00        2.00
# 7        25/2/2023        SP       M           8     1.00         NaN
# 8         8/3/2023        SP       M           5     4.00        2.00
# ...            ...       ...     ...         ...      ...         ...
# 278505   11/9/2023        MG       M           3     4.00        2.00
# 278507   30/9/2023        SP       M          76     4.00        2.00
# 278508   8/10/2023        SP       M           1     4.00        2.00
# 278510   1/12/2023        MG       F          91     1.00        1.00
# 278512  27/12/2023        MG       M           1     1.00        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 2             1.00      1.00        2.00      1.00        1.00
# 4             2.00      1.00        5.00      1.00        1.00
# 6             2.00      2.00        5.00      1.00        1.00
# 7             2.00      1.00        2.00      1.00        2.00
# 8             1.00      1.00        4.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 278505        2.00      1.00        4.00      1.00        2.00
# 278507        1.00      1.00        4.00      9.00        1.00
# 278508        2.00      1.00        2.00      1.00        2.00
# 278510        1.00      1.00        5.00      1.00        1.00
# 278512        1.00      1.00        4.00      1.00        2.00
#
# [127224 rows x 11 columns]

# %%
df_SE23.describe()
# Out:
#        NU_IDADE_N   CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count   127224.00 127224.00   112443.00   127223.00 125551.00   123893.00
# mean        36.10      3.22        2.32        1.51      1.03        3.81
# std         33.86      2.76        1.53        0.50      0.34        1.06
# min          0.00      1.00        1.00        1.00      0.00        1.00
# 25%          4.00      1.00        2.00        1.00      1.00        4.00
# 50%         21.00      2.00        2.00        2.00      1.00        4.00
# 75%         70.00      4.00        2.00        2.00      1.00        4.00
# max        100.00      9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count 119493.00   127200.00
# mean       1.33        1.54
# std        1.23        1.08
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_SE23["CS_SEXO"].value_counts()
# Out:
# M    64947
# F    62272
# I        5
# Name: CS_SEXO, dtype: int64

# %%
df_SE23["CS_RACA"].value_counts()
# Out:
# 1.00    60594
# 4.00    40705
# 9.00    19073
# 2.00     5674
# 3.00     1075
# 5.00      103
# Name: CS_RACA, dtype: int64

# %%
df_SE23["CLASSI_FIN"].value_counts()
# Out:
# 4.00    73091
# 5.00    27059
# 2.00    16185
# 1.00     5451
# 3.00     2107
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE23["EVOLUCAO"].value_counts()
# Out:
# 1.00    101149
# 2.00     12708
# 3.00      3012
# 9.00      2624
# Name: EVOLUCAO, dtype: int64

# %%
df_SE23["VACINA_COV"].value_counts()
# Out:
# 1.00    72943
# 2.00    52180
# 9.00     2077
# Name: VACINA_COV, dtype: int64

# %%
df_SE23["HOSPITAL"].value_counts()
# Out:
# 1.00    122939
# 2.00      2416
# 9.00       195
# 0.00         1
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE23, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2023');

# %%
sns.countplot(data=df_SE23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2023");

# %% [markdown]
# #### Análise Descritiva Sul(2023)

# %%
df_S23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "SC")| (tabela_2023["SG_UF_NOT"] == "RS") | (tabela_2023["SG_UF_NOT"] == "PR")]

# %%
df_S23
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       23/1/2023        RS       M          81     1.00        2.00
# 1       13/2/2023        SC       M          76     1.00        2.00
# 5       25/2/2023        PR       M           2     4.00        2.00
# 10       7/1/2023        PR       F          58     2.00        2.00
# 12      17/1/2023        SC       M          85     1.00        2.00
# ...           ...       ...     ...         ...      ...         ...
# 278485   2/6/2023        PR       M          67     1.00         NaN
# 278489  19/6/2023        RS       M          80     1.00        2.00
# 278490  11/6/2023        PR       M          76     9.00        2.00
# 278493  16/7/2023        RS       F          65     1.00        2.00
# 278497  22/5/2023        PR       F          67     4.00        1.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0             1.00      1.00        5.00      3.00        1.00
# 1             1.00      1.00        4.00      1.00        1.00
# 5             2.00      1.00        2.00      1.00        2.00
# 10            1.00      1.00        5.00      1.00        1.00
# 12            2.00      1.00        5.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 278485        2.00      1.00        4.00       NaN        1.00
# 278489        1.00      1.00        2.00      1.00        1.00
# 278490        2.00      1.00        4.00      1.00        1.00
# 278493        1.00      1.00        4.00      1.00        1.00
# 278497        1.00      1.00        3.00      3.00        1.00
#
# [55376 rows x 11 columns]

# %%
df_S23.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    55376.00 55376.00    50584.00    55376.00  54727.00    54665.00
# mean        34.77     2.22        2.10        1.50      1.01        3.50
# std         33.24     2.58        0.96        0.50      0.14        1.19
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          4.00     1.00        2.00        1.00      1.00        2.00
# 50%         16.00     1.00        2.00        1.00      1.00        4.00
# 75%         69.00     1.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  53603.00    55371.00
# mean       1.22        1.53
# std        0.82        0.89
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_S23["CS_SEXO"].value_counts()
# Out:
# M    28507
# F    26868
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_S23["CS_RACA"].value_counts()
# Out:
# 1.00    42335
# 9.00     6302
# 4.00     4920
# 2.00     1440
# 3.00      242
# 5.00      137
# Name: CS_RACA, dtype: int64

# %%
df_S23["CLASSI_FIN"].value_counts()
# Out:
# 4.00    27711
# 2.00    14078
# 5.00     9668
# 1.00     2724
# 3.00      484
# Name: CLASSI_FIN, dtype: int64

# %%
df_S23["EVOLUCAO"].value_counts()
# Out:
# 1.00    46710
# 2.00     4625
# 3.00     1858
# 9.00      410
# Name: EVOLUCAO, dtype: int64

# %%
df_S23["VACINA_COV"].value_counts()
# Out:
# 1.00    29686
# 2.00    25156
# 9.00      529
# Name: VACINA_COV, dtype: int64

# %%
df_S23["HOSPITAL"].value_counts()
# Out:
# 1.00    54416
# 2.00      299
# 9.00       12
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S23, x="NU_IDADE_N", color="red").set(title='Idade sul 2023');

# %%
sns.countplot(data=df_S23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2023");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2023)

# %%
df_CO23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "MS")| (tabela_2023["SG_UF_NOT"] == "MT") | (tabela_2023["SG_UF_NOT"] == "GO") | (tabela_2023["SG_UF_NOT"] == "DF")]

# %%
df_CO23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 11       11/1/2023        DF       M           2     4.00        2.00
# 16       15/1/2023        DF       F          93     9.00        1.00
# 19       17/2/2023        GO       M           1     9.00        2.00
# 30        5/4/2023        MS       F           6     4.00        2.00
# 31        1/1/2023        DF       M          72     9.00        2.00
# ...            ...       ...     ...         ...      ...         ...
# 278469   28/3/2023        MS       F          13     4.00        2.00
# 278476   29/4/2023        GO       F           3     4.00        2.00
# 278477   28/4/2023        GO       F          20     9.00        9.00
# 278480    5/5/2023        MS       F           1     4.00        2.00
# 278511  23/12/2023        GO       F           5     4.00        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 11            2.00      1.00        2.00      1.00        2.00
# 16            1.00      1.00        4.00      1.00        1.00
# 19            2.00      1.00        4.00      1.00        2.00
# 30            2.00      1.00        2.00      1.00        2.00
# 31            2.00      1.00        4.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 278469        1.00      1.00        1.00      1.00        1.00
# 278476        2.00      1.00        4.00      1.00        2.00
# 278477        2.00      1.00        4.00      1.00        1.00
# 278480        2.00      1.00        2.00      1.00        1.00
# 278511        2.00      1.00        4.00      1.00        2.00
#
# [28120 rows x 11 columns]

# %%
df_CO23.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    28120.00 28119.00    25989.00    28120.00  27997.00    27870.00
# mean        28.62     3.86        2.15        1.54      1.02        3.53
# std         31.62     2.23        1.14        0.50      0.22        1.21
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     3.00        2.00        1.00      1.00        2.00
# 50%          9.00     4.00        2.00        2.00      1.00        4.00
# 75%         60.00     4.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  27079.00    28115.00
# mean       1.16        1.64
# std        0.60        1.01
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_CO23["CS_SEXO"].value_counts()
# Out:
# M    14516
# F    13602
# I        1
# 1        1
# Name: CS_SEXO, dtype: int64

# %%
df_CO23 = df_CO23.loc[df_CO23["CS_SEXO"] != '1']

# %%
df_CO23["CS_RACA"].value_counts()
# Out:
# 4.00    17447
# 1.00     6257
# 9.00     3223
# 2.00      679
# 3.00      265
# 5.00      248
# Name: CS_RACA, dtype: int64

# %%
df_CO23["CLASSI_FIN"].value_counts()
# Out:
# 4.00    14926
# 2.00     5764
# 5.00     4899
# 1.00     2038
# 3.00      243
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO23["EVOLUCAO"].value_counts()
# Out:
# 1.00    24110
# 2.00     1974
# 3.00      922
# 9.00       73
# Name: EVOLUCAO, dtype: int64

# %%
df_CO23["VACINA_COV"].value_counts()
# Out:
# 2.00    14850
# 1.00    12872
# 9.00      393
# Name: VACINA_COV, dtype: int64

# %%
df_CO23["HOSPITAL"].value_counts()
# Out:
# 1.00    27575
# 2.00      406
# 9.00       15
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO23, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2023');

# %%
sns.countplot(data=df_CO23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2023");

# %% [markdown]
# #### Analise descritiva Norte (2023)

# %%
df_N23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "TO")| (tabela_2023["SG_UF_NOT"] == "PA") | (tabela_2023["SG_UF_NOT"] == "AP")  | (tabela_2023["SG_UF_NOT"] == "RR") | (tabela_2023["SG_UF_NOT"] == "AM") | (tabela_2023["SG_UF_NOT"] == "AC") | (tabela_2023["SG_UF_NOT"] == "RO")]

# %%
df_N23
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 17       5/2/2023        AM       M          60     5.00         NaN
# 74      25/1/2023        AC       F          78     4.00        2.00
# 88       8/4/2023        AP       F           1     1.00        2.00
# 98       5/4/2023        AM       M          78     4.00        2.00
# 110      1/5/2023        AM       M           5     9.00        9.00
# ...           ...       ...     ...         ...      ...         ...
# 278458   1/2/2023        RO       M          61     4.00        2.00
# 278463  13/2/2023        AM       M          26     4.00        1.00
# 278470  18/3/2023        RO       F          28     4.00         NaN
# 278481  29/4/2023        AP       F           7     4.00        2.00
# 278506   5/9/2023        AM       M           6     9.00         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 17            2.00      1.00        4.00      1.00        1.00
# 74            1.00      1.00        4.00      1.00        1.00
# 88            2.00      1.00        2.00      1.00        2.00
# 98            1.00      1.00         NaN       NaN        1.00
# 110           2.00      1.00        2.00      1.00        1.00
# ...            ...       ...         ...       ...         ...
# 278458        1.00      1.00        5.00      2.00        1.00
# 278463        1.00      1.00        4.00      1.00        1.00
# 278470        2.00       NaN         NaN       NaN        1.00
# 278481        2.00      1.00        4.00      1.00        2.00
# 278506        1.00      1.00        4.00      1.00        2.00
#
# [16982 rows x 11 columns]

# %%
df_N23.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    16982.00 16982.00    14346.00    16982.00  15710.00    15886.00
# mean        24.91     4.12        2.07        1.68      1.05        3.50
# std         29.94     1.57        0.87        0.47      0.43        1.13
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          2.00     4.00        2.00        1.00      1.00        2.00
# 50%          7.00     4.00        2.00        2.00      1.00        4.00
# 75%         50.00     4.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  15421.00    16975.00
# mean       1.35        1.72
# std        1.22        1.09
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_N23["CS_SEXO"].value_counts()
# Out:
# M    9065
# F    7913
# I       4
# Name: CS_SEXO, dtype: int64

# %%
df_N23["CS_RACA"].value_counts()
# Out:
# 4.00    13618
# 1.00     1307
# 9.00     1147
# 5.00      658
# 2.00      191
# 3.00       61
# Name: CS_RACA, dtype: int64

# %%
df_N23["EVOLUCAO"].value_counts()
# Out:
# 1.00    12980
# 2.00     1491
# 3.00      622
# 9.00      328
# Name: EVOLUCAO, dtype: int64

# %%
df_N23["CLASSI_FIN"].value_counts()
# Out:
# 4.00    9246
# 2.00    3344
# 5.00    1958
# 1.00     943
# 3.00     395
# Name: CLASSI_FIN, dtype: int64

# %%
df_N23["VACINA_COV"].value_counts()
# Out:
# 2.00    9833
# 1.00    6841
# 9.00     301
# Name: VACINA_COV, dtype: int64

# %%
df_N23["HOSPITAL"].value_counts()
# Out:
# 1.00    15145
# 2.00      528
# 9.00       37
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N23, x="NU_IDADE_N", color="blue").set(title='Idade norte 2023');

# %%
sns.countplot(data=df_N23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2023");

# %% [markdown]
# #### Analise descritiva Nordeste (2023)

# %%
df_NE23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "AL")| (tabela_2023["SG_UF_NOT"] == "BA") | (tabela_2023["SG_UF_NOT"] == "CE") | (tabela_2023["SG_UF_NOT"] == "MA") | (tabela_2023["SG_UF_NOT"] == "PB") | (tabela_2023["SG_UF_NOT"] == "PE") | (tabela_2023["SG_UF_NOT"] == "PI") | (tabela_2023["SG_UF_NOT"] == "RN") | (tabela_2023["SG_UF_NOT"] == "SE")]

# %%
df_NE23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 3        26/2/2023        CE       M           1     4.00         NaN
# 13       17/1/2023        PI       M           6     4.00         NaN
# 18        9/2/2023        PE       F          86     4.00        9.00
# 20       12/1/2023        CE       M           7     4.00        2.00
# 25       15/3/2023        CE       M           3     4.00        2.00
# ...            ...       ...     ...         ...      ...         ...
# 278496   14/7/2023        CE       M           1     4.00         NaN
# 278500   10/3/2023        CE       M           8     4.00        2.00
# 278501   13/8/2023        SE       M           3     9.00        2.00
# 278509  13/11/2023        BA       M          87     4.00         NaN
# 278513    6/7/2023        PE       M           1     1.00        2.00
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 3             2.00      1.00        4.00      1.00        1.00
# 13            2.00      1.00         NaN       NaN        2.00
# 18            2.00      1.00         NaN       NaN        1.00
# 20            2.00      1.00        4.00      1.00        2.00
# 25            2.00      1.00        1.00      1.00        2.00
# ...            ...       ...         ...       ...         ...
# 278496        2.00       NaN        4.00      1.00        1.00
# 278500        2.00      1.00        4.00      1.00        2.00
# 278501        1.00      1.00        4.00      1.00        2.00
# 278509        1.00      1.00        5.00      1.00        2.00
# 278513        2.00      1.00         NaN       NaN        2.00
#
# [50485 rows x 11 columns]

# %%
df_NE23.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    50485.00 50485.00    41501.00    50485.00  46617.00    46244.00
# mean        24.37     4.60        2.43        1.67      1.06        3.58
# std         30.81     2.30        1.76        0.47      0.54        1.10
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     4.00        2.00        1.00      1.00        3.00
# 50%          7.00     4.00        2.00        2.00      1.00        4.00
# 75%         50.00     4.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  44422.00    50464.00
# mean       1.65        1.78
# std        1.95        1.36
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_NE23["CS_SEXO"].value_counts()
# Out:
# M    26638
# F    23838
# I        9
# Name: CS_SEXO, dtype: int64

# %%
df_NE23["CS_RACA"].value_counts()
# Out:
# 4.00    34569
# 9.00     9435
# 1.00     4759
# 2.00     1242
# 3.00      309
# 5.00      171
# Name: CS_RACA, dtype: int64

# %%
df_NE23["CLASSI_FIN"].value_counts()
# Out:
# 4.00    28101
# 2.00     9260
# 5.00     6269
# 1.00     2237
# 3.00      377
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE23["EVOLUCAO"].value_counts()
# Out:
# 1.00    36455
# 2.00     3748
# 9.00     2778
# 3.00     1441
# Name: EVOLUCAO, dtype: int64

# %%
df_NE23["VACINA_COV"].value_counts()
# Out:
# 2.00    27105
# 1.00    21848
# 9.00     1511
# Name: VACINA_COV, dtype: int64

# %%
df_NE23["HOSPITAL"].value_counts()
# Out:
# 1.00    45280
# 2.00     1137
# 9.00      200
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE23, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2023');

# %%
sns.countplot(data=df_NE23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2023");

# %% [markdown]
# ### Descritivas (2024)

# %% [markdown]
# #### Análise Descritiva Sudeste (2024)

# %%
df_SE24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "ES")| (tabela_2024["SG_UF_NOT"] == "RJ") | (tabela_2024["SG_UF_NOT"] == "SP") | (tabela_2024["SG_UF_NOT"] == "MG")]

# %%
df_SE24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 9        1/1/2024        SP       F          77        1         NaN
# 14     31/12/2023        SP       F          78        9        2.00
# 17       2/1/2024        SP       F           1        4        2.00
# 21       3/1/2024        RJ       F          73        2        2.00
# 22       1/1/2024        SP       M          68        1        2.00
# ...           ...       ...     ...         ...      ...         ...
# 56112    1/4/2024        SP       M           4        9        2.00
# 56113   13/3/2024        MG       F          85        4        2.00
# 56114    1/4/2024        MG       F           1        9        2.00
# 56115    9/4/2024        SP       F           5        4        2.00
# 56117    7/4/2024        SP       M          63        4        9.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 9               1      1.00        5.00      1.00        1.00
# 14              1      1.00        4.00       NaN        1.00
# 17              2      1.00        1.00      1.00        2.00
# 21              1      1.00        3.00      2.00        1.00
# 22              1      1.00        4.00      1.00        1.00
# ...           ...       ...         ...       ...         ...
# 56112           2      1.00        2.00      1.00        2.00
# 56113           1      1.00        4.00       NaN        1.00
# 56114           2      1.00        2.00       NaN        1.00
# 56115           2      1.00        4.00       NaN        2.00
# 56117           2      2.00         NaN       NaN        1.00
#
# [25036 rows x 11 columns]

# %%
df_SE24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    25036.00 25036.00    21495.00    25036.00  24338.00    21349.00
# mean        39.61     3.25        2.26        1.49      1.05        3.78
# std         34.11     2.81        1.45        0.50      0.45        1.23
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          5.00     1.00        2.00        1.00      1.00        4.00
# 50%         38.00     2.00        2.00        1.00      1.00        4.00
# 75%         74.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count  17776.00    25022.00
# mean       1.52        1.61
# std        1.61        1.22
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_SE24["CS_SEXO"].value_counts()
# Out:
# M    12629
# F    12406
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_SE24["CS_RACA"].value_counts()
# Out:
# 1    11997
# 4     7734
# 9     3949
# 2     1141
# 3      189
# 5       26
# Name: CS_RACA, dtype: int64

# %%
df_SE24["CLASSI_FIN"].value_counts()
# Out:
# 4.00    9569
# 5.00    6652
# 2.00    3210
# 1.00    1483
# 3.00     435
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE24["EVOLUCAO"].value_counts()
# Out:
# 1.00    14192
# 2.00     2315
# 9.00      728
# 3.00      541
# Name: EVOLUCAO, dtype: int64

# %%
df_SE24["VACINA_COV"].value_counts()
# Out:
# 1.00    13613
# 2.00    10845
# 9.00      564
# Name: VACINA_COV, dtype: int64

# %%
df_SE24["HOSPITAL"].value_counts()
# Out:
# 1.00    23654
# 2.00      614
# 9.00       70
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE24, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2024');

# %%
sns.countplot(data=df_SE24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2024");

# %% [markdown]
# #### Análise Descritiva Sul(2024)

# %%
df_S24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "SC")| (tabela_2024["SG_UF_NOT"] == "RS") | (tabela_2024["SG_UF_NOT"] == "PR")]

# %%
df_S24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 1        1/1/2024        PR       F          88        1        2.00
# 2      31/12/2023        PR       M          26        1        2.00
# 4        3/1/2024        PR       M           2        1        2.00
# 5      31/12/2023        SC       M          76        1        2.00
# 6        3/1/2024        SC       M          77        1         NaN
# ...           ...       ...     ...         ...      ...         ...
# 56107   28/3/2024        SC       F          89        1        2.00
# 56108    4/4/2024        SC       F           4        1        2.00
# 56110    7/4/2024        PR       M           1        1        2.00
# 56119   19/3/2024        PR       F          76        1        2.00
# 56120    5/4/2024        PR       M          76        1        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 1               1      1.00        4.00      2.00        1.00
# 2               1      1.00        4.00      1.00        1.00
# 4               2      1.00        4.00      1.00        1.00
# 5               1      1.00        4.00      1.00        1.00
# 6               2      1.00        4.00      2.00        1.00
# ...           ...       ...         ...       ...         ...
# 56107           2      1.00        5.00       NaN        1.00
# 56108           2      1.00        2.00       NaN        2.00
# 56110           2      1.00         NaN       NaN        2.00
# 56119           2      1.00        5.00      2.00        1.00
# 56120           1      1.00         NaN       NaN        2.00
#
# [10604 rows x 11 columns]

# %%
df_S24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    10604.00 10604.00     9289.00    10604.00  10294.00     8942.00
# mean        42.05     1.92        2.09        1.45      1.01        3.69
# std         33.63     2.23        1.04        0.50      0.19        1.30
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          6.00     1.00        2.00        1.00      1.00        2.00
# 50%         47.00     1.00        2.00        1.00      1.00        4.00
# 75%         74.00     1.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count   7213.00    10603.00
# mean       1.33        1.57
# std        1.12        1.08
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        1.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_S24["CS_SEXO"].value_counts()
# Out:
# M    5409
# F    5194
# I       1
# Name: CS_SEXO, dtype: int64

# %%
df_S24["CS_RACA"].value_counts()
# Out:
# 1    8515
# 4     900
# 9     830
# 2     300
# 3      37
# 5      22
# Name: CS_RACA, dtype: int64

# %%
df_S24["CLASSI_FIN"].value_counts()
# Out:
# 4.00    3883
# 5.00    2694
# 2.00    1532
# 1.00     776
# 3.00      57
# Name: CLASSI_FIN, dtype: int64

# %%
df_S24["EVOLUCAO"].value_counts()
# Out:
# 1.00    5967
# 2.00     848
# 3.00     276
# 9.00     122
# Name: EVOLUCAO, dtype: int64

# %%
df_S24["VACINA_COV"].value_counts()
# Out:
# 1.00    5738
# 2.00    4691
# 9.00     174
# Name: VACINA_COV, dtype: int64

# %%
df_S24["HOSPITAL"].value_counts()
# Out:
# 1.00    10189
# 2.00      101
# 9.00        4
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S24, x="NU_IDADE_N", color="red").set(title='Idade sul 2024');

# %%
sns.countplot(data=df_S24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2024");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2024)

# %%
df_CO24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "MS")| (tabela_2024["SG_UF_NOT"] == "MT") | (tabela_2024["SG_UF_NOT"] == "GO") | (tabela_2024["SG_UF_NOT"] == "DF")]

# %%
df_CO24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 19       5/1/2024        GO       F          16        4        2.00
# 26       1/1/2024        MS       F          39        4        2.00
# 53       2/1/2024        MS       F          37        4        2.00
# 72     31/12/2023        MS       F          46        4        2.00
# 75     31/12/2023        GO       F           3        4        2.00
# ...           ...       ...     ...         ...      ...         ...
# 56076    5/4/2024        DF       M           1        4        2.00
# 56077   28/3/2024        DF       M          49        1        2.00
# 56105   31/3/2024        DF       M           1        1        2.00
# 56116   29/3/2024        GO       M           7        4        2.00
# 56121   12/4/2024        DF       F          70        1        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 19              2      1.00        4.00      1.00        1.00
# 26              1      1.00        4.00      1.00        1.00
# 53              1      1.00        4.00      1.00        1.00
# 72              1      1.00        5.00      2.00        1.00
# 75              2      1.00        4.00      1.00        2.00
# ...           ...       ...         ...       ...         ...
# 56076           2      1.00         NaN       NaN        2.00
# 56077           1      1.00        4.00      1.00        1.00
# 56105           2      1.00        2.00      1.00        2.00
# 56116           2      1.00        2.00       NaN        2.00
# 56121           1      1.00        4.00       NaN        1.00
#
# [5922 rows x 11 columns]

# %%
df_CO24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count     5922.00  5922.00     5533.00     5922.00   5834.00     5513.00
# mean        30.64     3.68        2.17        1.54      1.02        3.62
# std         32.16     2.16        1.25        0.50      0.21        1.23
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     2.00        2.00        1.00      1.00        2.00
# 50%         10.00     4.00        2.00        2.00      1.00        4.00
# 75%         63.00     4.00        2.00        2.00      1.00        5.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count   4504.00     5921.00
# mean       1.25        1.79
# std        0.96        1.42
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_CO24["CS_SEXO"].value_counts()
# Out:
# M    2983
# F    2939
# Name: CS_SEXO, dtype: int64

# %%
df_CO24["CS_RACA"].value_counts()
# Out:
# 4    3643
# 1    1472
# 9     568
# 2     156
# 3      50
# 5      33
# Name: CS_RACA, dtype: int64

# %%
df_CO24["CLASSI_FIN"].value_counts()
# Out:
# 4.00    2336
# 2.00    1513
# 5.00    1467
# 1.00     179
# 3.00      18
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO24["EVOLUCAO"].value_counts()
# Out:
# 1.00    3910
# 2.00     382
# 3.00     158
# 9.00      54
# Name: EVOLUCAO, dtype: int64

# %%
df_CO24["VACINA_COV"].value_counts()
# Out:
# 2.00    3097
# 1.00    2629
# 9.00     195
# Name: VACINA_COV, dtype: int64

# %%
df_CO24["HOSPITAL"].value_counts()
# Out:
# 1.00    5755
# 2.00      76
# 9.00       3
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO24, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2024');

# %%
sns.countplot(data=df_CO24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2024");

# %% [markdown]
# #### Analise descritiva Norte (2024)

# %%
df_N24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "TO")| (tabela_2024["SG_UF_NOT"] == "PA") | (tabela_2024["SG_UF_NOT"] == "AP")  | (tabela_2024["SG_UF_NOT"] == "RR") | (tabela_2024["SG_UF_NOT"] == "AM") | (tabela_2024["SG_UF_NOT"] == "AC") | (tabela_2024["SG_UF_NOT"] == "RO")]

# %%
df_N24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 7        1/1/2024        AM       F          88        4        2.00
# 10     31/12/2023        RO       M          17        4         NaN
# 23     31/12/2023        TO       M           1        4        2.00
# 86       4/1/2024        PA       F          56        4        2.00
# 106      1/1/2024        AM       F           6        4        2.00
# ...           ...       ...     ...         ...      ...         ...
# 56045   30/3/2024        TO       F           6        4        2.00
# 56053    6/4/2024        AC       F           2        5        9.00
# 56059   23/3/2024        AC       M           5        5        2.00
# 56069    5/4/2024        AC       F          92        4        2.00
# 56088   31/3/2024        RR       M           7        1        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 7               1      1.00        5.00      3.00        1.00
# 10              2      1.00        4.00      1.00        2.00
# 23              2      1.00        1.00      1.00        2.00
# 86              1      1.00        5.00      1.00        1.00
# 106             2      1.00        4.00      3.00        2.00
# ...           ...       ...         ...       ...         ...
# 56045           2      1.00         NaN       NaN        2.00
# 56053           2      1.00         NaN       NaN        2.00
# 56059           2      1.00        2.00      1.00        2.00
# 56069           1      1.00         NaN       NaN        1.00
# 56088           2      1.00        4.00      1.00        9.00
#
# [4197 rows x 11 columns]

# %%
df_N24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count     4197.00  4197.00     3589.00     4197.00   3969.00     3227.00
# mean        28.83     4.01        2.09        1.64      1.05        3.72
# std         31.13     1.42        0.98        0.48      0.40        1.14
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     4.00        2.00        1.00      1.00        4.00
# 50%          9.00     4.00        2.00        2.00      1.00        4.00
# 75%         60.00     4.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count   2697.00     4193.00
# mean       1.70        1.74
# std        1.95        1.22
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_N24["CS_SEXO"].value_counts()
# Out:
# M    2273
# F    1924
# Name: CS_SEXO, dtype: int64

# %%
df_N24["CS_RACA"].value_counts()
# Out:
# 4    3410
# 1     324
# 9     202
# 5     168
# 2      69
# 3      24
# Name: CS_RACA, dtype: int64

# %%
df_N24["CLASSI_FIN"].value_counts()
# Out:
# 4.00    1679
# 5.00     758
# 2.00     557
# 1.00     150
# 3.00      83
# Name: CLASSI_FIN, dtype: int64

# %%
df_N24["EVOLUCAO"].value_counts()
# Out:
# 1.00    2124
# 2.00     253
# 9.00     167
# 3.00     153
# Name: EVOLUCAO, dtype: int64

# %%
df_N24["VACINA_COV"].value_counts()
# Out:
# 2.00    2338
# 1.00    1758
# 9.00      97
# Name: VACINA_COV, dtype: int64

# %%
df_N24["HOSPITAL"].value_counts()
# Out:
# 1.00    3842
# 2.00     119
# 9.00       8
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N24, x="NU_IDADE_N", color="blue").set(title='Idade norte 2024');

# %%
sns.countplot(data=df_N24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2024");

# %% [markdown]
# #### Análise Descritiva Nordeste (2024)

# %%
df_NE24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "AL")| (tabela_2024["SG_UF_NOT"] == "BA") | (tabela_2024["SG_UF_NOT"] == "CE") | (tabela_2024["SG_UF_NOT"] == "MA") | (tabela_2024["SG_UF_NOT"] == "PB") | (tabela_2024["SG_UF_NOT"] == "PE") | (tabela_2024["SG_UF_NOT"] == "PI") | (tabela_2024["SG_UF_NOT"] == "RN") | (tabela_2024["SG_UF_NOT"] == "SE")]

# %%
df_NE24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        1/1/2024        CE       M          80        4        2.00
# 3        2/1/2024        CE       F          69        4        2.00
# 8        1/1/2024        PE       F          41        4        2.00
# 11       1/1/2024        RN       M           9        1        2.00
# 13     31/12/2023        AL       F          39        4        2.00
# ...           ...       ...     ...         ...      ...         ...
# 56087    5/4/2024        MA       F           1        4        2.00
# 56094   12/4/2024        PB       M          77        4        2.00
# 56095   13/3/2024        BA       F          29        4         NaN
# 56101    2/2/2024        PE       M          83        4         NaN
# 56118   15/3/2024        CE       M           1        1        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0               2      1.00         NaN       NaN        2.00
# 3               2      2.00        5.00       NaN        1.00
# 8               1      1.00         NaN       NaN        1.00
# 11              1      1.00        2.00      1.00        2.00
# 13              2      2.00        5.00      1.00        1.00
# ...           ...       ...         ...       ...         ...
# 56087           2      2.00        1.00      1.00        2.00
# 56094           1      1.00         NaN       NaN        1.00
# 56095           2      2.00        1.00      1.00        1.00
# 56101           2      1.00         NaN       NaN        1.00
# 56118           2      1.00        1.00      1.00        2.00
#
# [10283 rows x 11 columns]

# %%
df_NE24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count    10283.00 10283.00     8927.00    10283.00   9344.00     7515.00
# mean        28.47     4.40        2.56        1.60      1.08        3.45
# std         31.99     2.15        1.98        0.49      0.59        1.31
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     4.00        2.00        1.00      1.00        2.00
# 50%          9.00     4.00        2.00        2.00      1.00        4.00
# 75%         60.00     4.00        2.00        2.00      1.00        4.00
# max        100.00     9.00        9.00        2.00      9.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count   6375.00    10276.00
# mean       1.91        1.82
# std        2.27        1.47
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        1.00        2.00
# max        9.00        9.00

# %%
df_NE24["CS_SEXO"].value_counts()
# Out:
# M    5457
# F    4821
# I       5
# Name: CS_SEXO, dtype: int64

# %%
df_NE24["CS_RACA"].value_counts()
# Out:
# 4    7307
# 9    1557
# 1    1016
# 2     292
# 3      87
# 5      24
# Name: CS_RACA, dtype: int64

# %%
df_NE24["CLASSI_FIN"].value_counts()
# Out:
# 4.00    4284
# 1.00    1180
# 5.00    1136
# 2.00     802
# 3.00     113
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE24["EVOLUCAO"].value_counts()
# Out:
# 1.00    4827
# 2.00     738
# 9.00     570
# 3.00     240
# Name: EVOLUCAO, dtype: int64

# %%
df_NE24["VACINA_COV"].value_counts()
# Out:
# 2.00    5444
# 1.00    4464
# 9.00     368
# Name: VACINA_COV, dtype: int64

# %%
df_NE24["HOSPITAL"].value_counts()
# Out:
# 1.00    8961
# 2.00     336
# 9.00      47
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE24, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2024');

# %%
sns.countplot(data=df_NE24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2024");

# %% [markdown]
# ### Juntando tabelas

# %%
tabelas = [tabela_2021, tabela_2022, tabela_2023, tabela_2024]
df_BRASIL = pd.concat(tabelas, ignore_index=True)

# %%
df_BRASIL
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        06/01/2021        BA       M          69     1.00         NaN
# 1        03/01/2021        BA       M          89     9.00         NaN
# 2        07/01/2021        PR       F          51     9.00        2.00
# 3        05/01/2021        PR       M          57     2.00        2.00
# 4        04/01/2021        RS       M          81     1.00        2.00
# ...             ...       ...     ...         ...      ...         ...
# 1938142    7/4/2024        SP       M          63     4.00        9.00
# 1938143   15/3/2024        CE       M           1     1.00        2.00
# 1938144   19/3/2024        PR       F          76     1.00        2.00
# 1938145    5/4/2024        PR       M          76     1.00        2.00
# 1938146   12/4/2024        DF       F          70     1.00        2.00
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0              2.00      1.00        3.00      2.00         NaN
# 1              2.00      1.00        5.00      2.00         NaN
# 2              1.00      1.00        4.00      1.00         NaN
# 3              1.00      1.00        4.00      3.00         NaN
# 4              1.00      1.00        5.00      2.00         NaN
# ...             ...       ...         ...       ...         ...
# 1938142        2.00      2.00         NaN       NaN        1.00
# 1938143        2.00      1.00        1.00      1.00        2.00
# 1938144        2.00      1.00        5.00      2.00        1.00
# 1938145        1.00      1.00         NaN       NaN        2.00
# 1938146        1.00      1.00        4.00       NaN        1.00
#
# [1938147 rows x 11 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df_BRASIL.describe()
# Out:
#        NU_IDADE_N    CS_RACA  NOSOCOMIAL  FATOR_RISC   HOSPITAL  CLASSI_FIN  \
# count  1938147.00 1938146.00  1633977.00  1938146.00 1882326.00  1838463.00
# mean        48.38       3.48        2.46        1.46       1.03        4.38
# std         28.61       2.80        1.79        0.50       0.37        0.91
# min          0.00       1.00        1.00        1.00       0.00        1.00
# 25%         26.00       1.00        2.00        1.00       1.00        4.00
# 50%         54.00       4.00        2.00        1.00       1.00        5.00
# 75%         72.00       4.00        2.00        2.00       1.00        5.00
# max        100.00       9.00        9.00        2.00       9.00        5.00
#
#         EVOLUCAO  VACINA_COV
# count 1753353.00  1668129.00
# mean        1.48        2.37
# std         1.36        2.46
# min         1.00        1.00
# 25%         1.00        1.00
# 50%         1.00        2.00
# 75%         2.00        2.00
# max         9.00        9.00

# %%
labels = ['Feminino', 'Masculino']
sizes = [914672,1025734]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['orange', 'skyblue'])
plt.axis('equal')
plt.title('Distribuição de Gênero dos Casos de SRAG de 2021 a 2024')
plt.show()

# %%
sns.countplot(data=df_BRASIL, x='CS_RACA').set(title='Distribuição das Raças dos Indivíduos com SRAG de 2021 a 2024');

# %%
evolucao_counts = df_BRASIL["EVOLUCAO"].value_counts()
mapeamento_evolucao = {1.00: 'Cura', 2.00: 'Óbito', 3.00: 'Óbito por outras causas', 9.00: 'Ignorado'}
evolucao_counts.index = evolucao_counts.index.map(mapeamento_evolucao)
plt.figure(figsize=(10, 6))
sns.barplot(x=evolucao_counts.index, y=evolucao_counts.values, palette='viridis')
plt.title('Evolução dos Casos de SRAG no Brasil (2021-2024)')
plt.xlabel('Evolução')
plt.ylabel('Quantidade')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
labels = ['Recebeu a vacina', 'Não recebeu a vacina','Ignorado']
sizes = [753807,721913,194709]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['orange', 'skyblue','purple'])
plt.axis('equal')
plt.title('Distribuição da Verificação de Vacinação contra COVID-19 (2021-2024)')
plt.show()

# %%
hospital_counts = df_BRASIL["HOSPITAL"].value_counts()
mapeamento_hospital = {1.00: 'Internado', 2.00: 'Não internado', 9.00: 'Ignorado'}
hospital_counts.index = hospital_counts.index.map(mapeamento_hospital)
plt.figure(figsize=(10, 6))
sns.barplot(x=hospital_counts.index, y=hospital_counts.values, palette='viridis')
plt.title('Internação de Pacientes com Casos de SRAG no Brasil (2021-2024)')
plt.xlabel('Internação')
plt.ylabel('Quantidade')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ### Análises dos estados do nordeste

# %% [markdown]
# * Maranhão

# %%
df_MA24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "MA")]
df_MA24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 20     31/12/2023        MA       M          58        4        2.00
# 27       2/1/2024        MA       M           0        4        2.00
# 254      1/1/2024        MA       M          81        4        2.00
# 375      8/1/2024        MA       F          43        4        2.00
# 576     14/1/2024        MA       F          50        1        2.00
# ...           ...       ...     ...         ...      ...         ...
# 55838   27/3/2024        MA       F          11        4        2.00
# 55947   29/3/2024        MA       M          13        4         NaN
# 55993   18/3/2024        MA       M           3        4         NaN
# 56078    1/4/2024        MA       M           5        4        2.00
# 56087    5/4/2024        MA       F           1        4        2.00
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 20              1      1.00        5.00      2.00        1.00
# 27              2      1.00        4.00      1.00        2.00
# 254             1      1.00        4.00      1.00        1.00
# 375             1      1.00        4.00       NaN        2.00
# 576             2      1.00        5.00      1.00        1.00
# ...           ...       ...         ...       ...         ...
# 55838           2      1.00        1.00      2.00        2.00
# 55947           1      1.00        4.00       NaN        1.00
# 55993           2      1.00        4.00      1.00        1.00
# 56078           2      2.00        1.00      1.00        1.00
# 56087           2      2.00        1.00      1.00        2.00
#
# [661 rows x 11 columns]

# %%
df_MA24.describe()
# Out:
#        NU_IDADE_N  CS_RACA  NOSOCOMIAL  FATOR_RISC  HOSPITAL  CLASSI_FIN  \
# count      661.00   661.00      572.00      661.00    613.00      500.00
# mean        22.47     4.20        2.13        1.75      1.11        2.78
# std         28.47     1.75        1.06        0.43      0.32        1.52
# min          0.00     1.00        1.00        1.00      1.00        1.00
# 25%          3.00     4.00        2.00        1.00      1.00        1.00
# 50%          7.00     4.00        2.00        2.00      1.00        4.00
# 75%         43.00     4.00        2.00        2.00      1.00        4.00
# max         99.00     9.00        9.00        2.00      2.00        5.00
#
#        EVOLUCAO  VACINA_COV
# count    335.00      661.00
# mean       1.80        1.82
# std        2.09        1.19
# min        1.00        1.00
# 25%        1.00        1.00
# 50%        1.00        2.00
# 75%        2.00        2.00
# max        9.00        9.00

# %%
labels = ['Feminino', 'Masculino']
sizes = [311,348]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['orange', 'skyblue'])
plt.axis('equal')
plt.title('Distribuição de Gênero dos Casos de SRAG no Maranhão em 2024')
plt.show()

# %%
sns.countplot(data=df_MA24, x='CS_RACA').set(title='Distribuição das Raças dos Indivíduos com SRAG no Maranhão em 2024');

# %%
evolucao_counts = df_MA24["EVOLUCAO"].value_counts()
mapeamento_evolucao = {1.00: 'Cura', 2.00: 'Óbito', 3.00: 'Óbito por outras causas', 9.00: 'Ignorado'}
evolucao_counts.index = evolucao_counts.index.map(mapeamento_evolucao)
plt.figure(figsize=(10, 6))
sns.barplot(x=evolucao_counts.index, y=evolucao_counts.values, palette='viridis')
plt.title('Evolução dos Casos de SRAG no Maranhão (2024)')
plt.xlabel('Evolução')
plt.ylabel('Quantidade')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
labels = ['Recebeu a vacina', 'Não recebeu a vacina','Ignorado']
sizes = [225,421,15]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['orange', 'skyblue','pink'])
plt.axis('equal')
plt.title('Distribuição da Verificação de Vacinação contra COVID-19 no Maranhão (2024)')
plt.show()

# %%
hospital_counts = df_MA24["HOSPITAL"].value_counts()
mapeamento_hospital = {1.00: 'Internado', 2.00: 'Não internado', 9.00: 'Ignorado'}
hospital_counts.index = hospital_counts.index.map(mapeamento_hospital)
plt.figure(figsize=(10, 6))
sns.barplot(x=hospital_counts.index, y=hospital_counts.values, palette='viridis')
plt.title('Internação de Pacientes com Casos de SRAG no Maranhão (2024)')
plt.xlabel('Internação')
plt.ylabel('Quantidade')
plt.ticklabel_format(style='plain', axis='y')
plt.show()
