# %% [markdown]
# ### Importando bibliotecas e lendo tabelas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
tabela_2021 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD21-01-05-2023.csv", sep=";", usecols=["DT_SIN_PRI","SG_UF_NOT","CS_SEXO",
                                                                                             "NU_IDADE_N", "CS_RACA", "NOSOCOMIAL",
                                                                                             "FATOR_RISC", "VACINA_COV", "HOSPITAL",
                                                                                             "CLASSI_FIN", "EVOLUCAO"])

# %%
tabela_2022 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD22-03-04-2023.csv", sep=";", usecols=["DT_SIN_PRI","SG_UF_NOT","CS_SEXO",
                                                                                             "NU_IDADE_N", "CS_RACA", "NOSOCOMIAL",
                                                                                             "FATOR_RISC", "VACINA_COV", "HOSPITAL",
                                                                                             "CLASSI_FIN", "EVOLUCAO"])

# %%
tabela_2023 = pd.read_csv("C:\\Users\\amand\\Downloads\\INFLUD23-15-04-2024.csv", sep=";")

# %%
tabela_2024 = pd.read_csv("C:\\Users\\amand\\Downloads\\2024.csv", sep=";")

# %%
tabela_2021
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        06/01/2021        BA       M          69        1         NaN
# 1        03/01/2021        BA       M          89        9         NaN
# 2        07/01/2021        PR       F          51        9         2.0
# 3        05/01/2021        PR       M          57        2         2.0
# 4        04/01/2021        RS       M          81        1         2.0
# ...             ...       ...     ...         ...      ...         ...
# 1048570  27/03/2021        BA       F          82        9         2.0
# 1048571  28/02/2021        RS       M          52        2         2.0
# 1048572  12/03/2021        MG       F          62        4         2.0
# 1048573  22/03/2021        MG       M          31        4         2.0
# 1048574  01/03/2021        RJ       F          80        9         2.0
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
tabela_2022
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       02/01/2022        RJ       M          23        4         NaN
# 1       03/01/2022        MS       F          37        4         2.0
# 2       04/01/2022        GO       F          33        4         2.0
# 3       04/01/2022        GO       M          76        4         1.0
# 4       06/01/2022        SP       F          16        1         NaN
# ...            ...       ...     ...         ...      ...         ...
# 557471  25/11/2022        PI       F          87        4         2.0
# 557472  25/06/2022        SC       M          27        1         2.0
# 557473  26/11/2022        PE       M          73        9         NaN
# 557474  26/07/2022        RO       F           1        4         NaN
# 557475  10/02/2022        SP       F          86        1         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                2       1.0         4.0       1.0         1.0
# ...

# %%
tabela_2023
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        23/1/2023        RS       M          81      1.0         2.0
# 1        13/2/2023        SC       M          76      1.0         2.0
# 2        24/2/2023        RJ       M           8      4.0         2.0
# 3        26/2/2023        CE       M           1      4.0         NaN
# 4         4/2/2023        SP       F          18      1.0         NaN
# ...            ...       ...     ...         ...      ...         ...
# 278509  13/11/2023        BA       M          87      4.0         NaN
# 278510   1/12/2023        MG       F          91      1.0         1.0
# 278511  23/12/2023        GO       F           5      4.0         2.0
# 278512  27/12/2023        MG       M           1      1.0         2.0
# 278513    6/7/2023        PE       M           1      1.0         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0              1.0       1.0         5.0       3.0         1.0
# ...

# %%
tabela_2024
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        1/1/2024        CE       M          80        4         2.0
# 1        1/1/2024        PR       F          88        1         2.0
# 2      31/12/2023        PR       M          26        1         2.0
# 3        2/1/2024        CE       F          69        4         2.0
# 4        3/1/2024        PR       M           2        1         2.0
# ...           ...       ...     ...         ...      ...         ...
# 56117    7/4/2024        SP       M          63        4         9.0
# 56118   15/3/2024        CE       M           1        1         2.0
# 56119   19/3/2024        PR       F          76        1         2.0
# 56120    5/4/2024        PR       M          76        1         2.0
# 56121   12/4/2024        DF       F          70        1         2.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0               2       1.0         NaN       NaN         2.0
# ...

# %% [markdown]
# ### Descritivas (2021)

# %% [markdown]
# #### Análise Descritiva Sudeste (2021)

# %%
df_SE = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "ES")| (tabela_2021["SG_UF_NOT"] == "RJ") | (tabela_2021["SG_UF_NOT"] == "SP") | (tabela_2021["SG_UF_NOT"] == "MG")]

# %%
df_SE
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 5        04/01/2021        RJ       M          64        1         2.0
# 7        04/01/2021        RJ       F          63        1         NaN
# 8        04/01/2021        RJ       F           9        2         NaN
# 9        03/01/2021        SP       F          64        9         2.0
# 11       11/01/2021        SP       F          28        1         NaN
# ...             ...       ...     ...         ...      ...         ...
# 1048565  21/03/2021        SP       F          56        4         9.0
# 1048567  15/03/2021        MG       F          79        4         2.0
# 1048572  12/03/2021        MG       F          62        4         2.0
# 1048573  22/03/2021        MG       M          31        4         2.0
# 1048574  01/03/2021        RJ       F          80        9         2.0
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
df_SE.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  519895.000000  519895.000000  437833.000000  519895.000000
# mean       54.010169       3.338786       2.701631       1.432928
# std        22.578200       2.908295       2.132791       0.495481
# min        -9.000000       1.000000       1.000000       1.000000
# 25%        41.000000       1.000000       2.000000       1.000000
# 50%        57.000000       2.000000       2.000000       1.000000
# 75%        70.000000       4.000000       2.000000       2.000000
# max       136.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  509767.000000  502787.000000  483791.000000  401247.000000
# mean        1.034579       4.662026       1.464676       3.139126
# std         0.384942       0.644278       1.205310       3.063380
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_SE["CS_SEXO"].value_counts()
# Out:
# M    281790
# F    238040
# I        65
# Name: CS_SEXO, dtype: int64

# %%
df_SE["CS_RACA"].value_counts()
# Out:
# 1    246552
# 4    148213
# 9     91470
# 2     28426
# 3      4919
# 5       315
# Name: CS_RACA, dtype: int64

# %%
df_SE["CLASSI_FIN"].value_counts()
# Out:
# 5.0    360428
# 4.0    130207
# 2.0      5188
# 1.0      5115
# 3.0      1849
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE["EVOLUCAO"].value_counts()
# Out:
# 1.0    336157
# 2.0    131626
# 9.0     10194
# 3.0      5814
# Name: EVOLUCAO, dtype: int64

# %%
df_SE["VACINA_COV"].value_counts()
# Out:
# 2.0    180726
# 1.0    135822
# 9.0     84699
# Name: VACINA_COV, dtype: int64

# %%
df_SE["HOSPITAL"].value_counts()
# Out:
# 1.0    499455
# 2.0      9267
# 9.0      1045
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2021');

# %%
sns.countplot(data=df_SE, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2021");

# %% [markdown]
# 1 = sim, 2 = não, 9 = ignorado

# %% [markdown]
# #### Análise Descritiva Sul(2021)

# %%
df_S = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "SC")| (tabela_2021["SG_UF_NOT"] == "RS") | (tabela_2021["SG_UF_NOT"] == "PR")]

# %%
df_S
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 2        07/01/2021        PR       F          51        9         2.0
# 3        05/01/2021        PR       M          57        2         2.0
# 4        04/01/2021        RS       M          81        1         2.0
# 10       04/01/2021        PR       F          26        1         2.0
# 14       07/01/2021        SC       F           3        1         NaN
# ...             ...       ...     ...         ...      ...         ...
# 1048550  13/05/2021        PR       M          66        4         2.0
# 1048552  08/05/2021        PR       F          34        1         2.0
# 1048557  30/04/2021        SC       F          29        1         2.0
# 1048566  04/02/2021        PR       F          45        1         2.0
# 1048571  28/02/2021        RS       M          52        2         2.0
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
df_S.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  184958.000000  184958.000000  162336.000000  184958.000000
# mean       54.127737       2.128618       2.203886       1.391019
# std        21.384536       2.532967       1.236686       0.487980
# min        -2.000000       1.000000       1.000000       1.000000
# 25%        42.000000       1.000000       2.000000       1.000000
# 50%        56.000000       1.000000       2.000000       1.000000
# 75%        70.000000       1.000000       2.000000       2.000000
# max       113.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  183693.000000  182153.000000  173567.000000  142062.000000
# mean        1.014230       4.710611       1.471973       2.880989
# std         0.205863       0.605645       1.209151       2.828826
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_S["CS_SEXO"].value_counts()
# Out:
# M    101692
# F     83255
# I        11
# Name: CS_SEXO, dtype: int64

# %%
df_S["CS_RACA"].value_counts()
# Out:
# 1    145401
# 9     20178
# 4     13111
# 2      5026
# 3      1002
# 5       240
# Name: CS_RACA, dtype: int64

# %%
df_S["CLASSI_FIN"].value_counts()
# Out:
# 5.0    138990
# 4.0     38398
# 2.0      4099
# 1.0       343
# 3.0       323
# Name: CLASSI_FIN, dtype: int64

# %%
df_S["EVOLUCAO"].value_counts()
# Out:
# 1.0    120419
# 2.0     46229
# 9.0      3642
# 3.0      3277
# Name: EVOLUCAO, dtype: int64

# %%
df_S["VACINA_COV"].value_counts()
# Out:
# 2.0    71185
# 1.0    46373
# 9.0    24504
# Name: VACINA_COV, dtype: int64

# %%
df_S["HOSPITAL"].value_counts()
# Out:
# 1.0    181730
# 2.0      1870
# 9.0        93
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S, x="NU_IDADE_N", color="red").set(title='Idade sul 2021');

# %%
sns.countplot(data=df_S, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2021");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2021)

# %%
df_CO = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "MS")| (tabela_2021["SG_UF_NOT"] == "MT") | (tabela_2021["SG_UF_NOT"] == "GO")]

# %%
df_CO
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 16       08/01/2021        MS       M          84        1         9.0
# 60       05/01/2021        MT       F          44        4         2.0
# 64       08/01/2021        GO       F           9        4         2.0
# 100      07/01/2021        MT       M          73        4         NaN
# 132      07/01/2021        MS       M          37        4         2.0
# ...             ...       ...     ...         ...      ...         ...
# 1048441  16/03/2021        MT       F          41        4         2.0
# 1048442  07/05/2021        MS       M          45        1         2.0
# 1048465  10/03/2021        GO       F          52        9         NaN
# 1048466  12/02/2021        GO       F          45        4         2.0
# 1048517  09/03/2021        MS       F          43        1         NaN
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
df_CO.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  72115.000000  72115.000000  61031.000000  72115.000000  69653.000000
# mean      53.141871      3.862775      2.346562      1.495570      1.032863
# std       19.857053      2.520829      1.562709      0.499984      0.364811
# min       -1.000000      1.000000      1.000000      1.000000      1.000000
# 25%       40.000000      1.000000      2.000000      1.000000      1.000000
# 50%       54.000000      4.000000      2.000000      1.000000      1.000000
# 75%       67.000000      4.000000      2.000000      2.000000      1.000000
# max      110.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  71328.000000  69523.000000  54134.000000
# mean       4.787293      1.397408      3.220730
# std        0.556492      0.968366      3.044748
# min        1.000000      1.000000      1.000000
# ...

# %%
df_CO["CS_SEXO"].value_counts()
# Out:
# M    40026
# F    32088
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_CO["CS_RACA"].value_counts()
# Out:
# 4    37771
# 1    19491
# 9    10896
# 2     2612
# 3     1012
# 5      333
# Name: CS_RACA, dtype: int64

# %%
df_CO["CLASSI_FIN"].value_counts()
# Out:
# 5.0    59140
# 4.0    10865
# 2.0      807
# 1.0      427
# 3.0       89
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO["EVOLUCAO"].value_counts()
# Out:
# 1.0    48400
# 2.0    19693
# 9.0      846
# 3.0      584
# Name: EVOLUCAO, dtype: int64

# %%
df_CO["VACINA_COV"].value_counts()
# Out:
# 2.0    27561
# 1.0    14991
# 9.0    11582
# Name: VACINA_COV, dtype: int64

# %%
df_CO["HOSPITAL"].value_counts()
# Out:
# 1.0    68246
# 2.0     1281
# 9.0      126
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2021');

# %%
sns.countplot(data=df_CO, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2021");

# %% [markdown]
# #### Analise descritiva Norte (2021)

# %%
df_N = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "TO")| (tabela_2021["SG_UF_NOT"] == "PA") | (tabela_2021["SG_UF_NOT"] == "AP")  | (tabela_2021["SG_UF_NOT"] == "RR") | (tabela_2021["SG_UF_NOT"] == "AM") | (tabela_2021["SG_UF_NOT"] == "AC") | (tabela_2021["SG_UF_NOT"] == "RO")]

# %%
df_N
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 20       09/01/2021        AM       F           2        4         2.0
# 32       03/01/2021        PA       M          83        4         NaN
# 62       05/01/2021        TO       M          69        4         2.0
# 92       05/01/2021        PA       F          77        4         2.0
# 93       10/01/2021        TO       F          26        4         1.0
# ...             ...       ...     ...         ...      ...         ...
# 1048526  24/02/2021        AC       F          86        3         NaN
# 1048535  11/03/2021        PA       F          49        1         2.0
# 1048541  25/03/2021        TO       M          89        4         2.0
# 1048544  01/05/2021        AC       M          69        4         2.0
# 1048555  05/04/2021        TO       M          72        4         2.0
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
df_N.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  62745.000000  62745.000000  49900.000000  62745.000000  58728.000000
# mean      52.239206      3.904423      2.267675      1.567121      1.048750
# std       21.520791      1.506138      1.424701      0.495478      0.416171
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%       39.000000      4.000000      2.000000      1.000000      1.000000
# 50%       54.000000      4.000000      2.000000      2.000000      1.000000
# 75%       68.000000      4.000000      2.000000      2.000000      1.000000
# max      127.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  58083.000000  54421.000000  40578.000000
# mean       4.746811      1.652487      3.569249
# std        0.551138      1.537942      3.187196
# min        1.000000      1.000000      1.000000
# ...

# %%
df_N["CS_SEXO"].value_counts()
# Out:
# M    34559
# F    28165
# I       21
# Name: CS_SEXO, dtype: int64

# %%
df_N["CS_RACA"].value_counts()
# Out:
# 4    50422
# 1     6044
# 9     3190
# 2     1890
# 3      617
# 5      582
# Name: CS_RACA, dtype: int64

# %%
df_N["CLASSI_FIN"].value_counts()
# Out:
# 5.0    45336
# 4.0    11829
# 2.0      381
# 1.0      330
# 3.0      207
# Name: CLASSI_FIN, dtype: int64

# %%
df_N["EVOLUCAO"].value_counts()
# Out:
# 1.0    34114
# 2.0    17387
# 9.0     2047
# 3.0      873
# Name: EVOLUCAO, dtype: int64

# %%
df_N["VACINA_COV"].value_counts()
# Out:
# 2.0    21999
# 9.0    10282
# 1.0     8297
# Name: VACINA_COV, dtype: int64

# %%
df_N["HOSPITAL"].value_counts()
# Out:
# 1.0    56796
# 2.0     1799
# 9.0      133
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N, x="NU_IDADE_N", color="blue").set(title='Idade norte 2021');

# %%
sns.countplot(data=df_N, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2021");

# %% [markdown]
# #### Analise descritiva Nordeste (2021)

# %%
df_NE = tabela_2021.loc[(tabela_2021["SG_UF_NOT"] == "AL")| (tabela_2021["SG_UF_NOT"] == "BA") | (tabela_2021["SG_UF_NOT"] == "CE") | (tabela_2021["SG_UF_NOT"] == "MA") | (tabela_2021["SG_UF_NOT"] == "PB") | (tabela_2021["SG_UF_NOT"] == "PE") | (tabela_2021["SG_UF_NOT"] == "PI") | (tabela_2021["SG_UF_NOT"] == "RN") | (tabela_2021["SG_UF_NOT"] == "SE")]

# %%
df_NE
# Out:
#          DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        06/01/2021        BA       M          69        1         NaN
# 1        03/01/2021        BA       M          89        9         NaN
# 6        06/01/2021        CE       F          89        4         2.0
# 15       04/01/2021        PB       F           1        1         2.0
# 25       04/01/2021        SE       F          70        1         2.0
# ...             ...       ...     ...         ...      ...         ...
# 1048547  11/05/2021        RN       M          18        4         2.0
# 1048553  14/05/2021        BA       M          38        9         2.0
# 1048564  16/03/2021        PI       M          79        4         2.0
# 1048568  19/03/2021        BA       M          53        4         2.0
# 1048570  27/03/2021        BA       F          82        9         2.0
#
#          FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# ...

# %%
df_NE.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  188219.000000  188219.000000  135182.000000  188219.000000
# mean       52.713111       4.805105       2.680364       1.456415
# std        23.530100       2.535847       2.120193       0.498098
# min         0.000000       1.000000       1.000000       1.000000
# 25%        39.000000       4.000000       2.000000       1.000000
# 50%        55.000000       4.000000       2.000000       1.000000
# 75%        70.000000       4.000000       2.000000       2.000000
# max       150.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  177972.000000  165568.000000  152739.000000  124352.000000
# mean        1.047159       4.644382       1.825395       3.879560
# std         0.436603       0.641943       1.891422       3.437869
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_NE["CS_SEXO"].value_counts()
# Out:
# M    101812
# F     86333
# I        74
# Name: CS_SEXO, dtype: int64

# %%
df_NE["CS_RACA"].value_counts()
# Out:
# 4    114911
# 9     45056
# 1     19842
# 2      6318
# 3      1837
# 5       255
# Name: CS_RACA, dtype: int64

# %%
df_NE["CLASSI_FIN"].value_counts()
# Out:
# 5.0    115158
# 4.0     46691
# 1.0      1925
# 2.0       900
# 3.0       894
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE["EVOLUCAO"].value_counts()
# Out:
# 1.0    94222
# 2.0    46578
# 9.0     9269
# 3.0     2670
# Name: EVOLUCAO, dtype: int64

# %%
df_NE["VACINA_COV"].value_counts()
# Out:
# 2.0    51975
# 9.0    38263
# 1.0    34114
# Name: VACINA_COV, dtype: int64

# %%
df_NE["HOSPITAL"].value_counts()
# Out:
# 1.0    172820
# 2.0      4689
# 9.0       463
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2021');

# %%
sns.countplot(data=df_NE, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2021");

# %% [markdown]
# ### Descritivas (2022)

# %% [markdown]
# #### Analise descritiva Sudeste (2022)

# %%
df_SE22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "ES")| (tabela_2022["SG_UF_NOT"] == "RJ") | (tabela_2022["SG_UF_NOT"] == "SP") | (tabela_2022["SG_UF_NOT"] == "MG")]

# %%
df_SE22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       02/01/2022        RJ       M          23        4         NaN
# 4       06/01/2022        SP       F          16        1         NaN
# 7       08/01/2022        SP       M          55        9         NaN
# 10      07/01/2022        SP       M           1        1         NaN
# 11      06/01/2022        MG       F          50        4         2.0
# ...            ...       ...     ...         ...      ...         ...
# 557462  27/11/2022        RJ       M           4        4         2.0
# 557465  13/12/2022        SP       M           2        4         2.0
# 557466  03/12/2022        SP       M          52        1         2.0
# 557468  23/12/2022        SP       F          62        1         2.0
# 557475  10/02/2022        SP       F          86        1         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0                2       1.0         4.0       1.0         1.0
# ...

# %%
df_SE22.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  273623.000000  273623.000000  236427.000000  273623.000000
# mean       49.847911       3.380337       2.510229       1.429134
# std        32.650080       2.940762       1.888855       0.494953
# min        -9.000000       1.000000       1.000000       1.000000
# 25%         9.000000       1.000000       2.000000       1.000000
# 50%        61.000000       2.000000       2.000000       1.000000
# 75%        78.000000       4.000000       2.000000       2.000000
# max       115.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  269079.000000  264801.000000  251862.000000  273563.000000
# mean        1.034611       4.312336       1.457929       1.544280
# std         0.399936       0.849961       1.378289       1.289325
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_SE22["CS_SEXO"].value_counts()
# Out:
# M    137616
# F    135989
# I        18
# Name: CS_SEXO, dtype: int64

# %%
df_SE22["CS_RACA"].value_counts()
# Out:
# 1    130415
# 4     78043
# 9     49804
# 2     12392
# 3      2757
# 5       212
# Name: CS_RACA, dtype: int64

# %%
df_SE22["CLASSI_FIN"].value_counts()
# Out:
# 4.0    123327
# 5.0    123004
# 2.0     11649
# 1.0      5089
# 3.0      1732
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE22["EVOLUCAO"].value_counts()
# Out:
# 1.0    192602
# 2.0     46583
# 9.0      7233
# 3.0      5444
# Name: EVOLUCAO, dtype: int64

# %%
df_SE22["VACINA_COV"].value_counts()
# Out:
# 1.0    173031
# 2.0     93623
# 9.0      6909
# Name: VACINA_COV, dtype: int64

# %%
df_SE22["HOSPITAL"].value_counts()
# Out:
# 1.0    264022
# 2.0      4449
# 9.0       608
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE22, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2022');

# %%
sns.countplot(data=df_SE22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2022");

# %% [markdown]
# #### Análise Descritiva Sul(2022)

# %%
df_S22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "SC")| (tabela_2022["SG_UF_NOT"] == "RS") | (tabela_2022["SG_UF_NOT"] == "PR")]

# %%
df_S22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 6       02/01/2022        SC       M          75        1         2.0
# 9       02/01/2022        RS       M          55        1         NaN
# 13      06/01/2022        PR       M          69        1         2.0
# 22      10/01/2022        SC       M           2        1         2.0
# 23      13/01/2022        SC       F          94        1         2.0
# ...            ...       ...     ...         ...      ...         ...
# 557464  17/12/2022        PR       F           2        1         2.0
# 557467  18/12/2022        PR       F          70        1         2.0
# 557469  12/12/2022        RS       F          72        9         NaN
# 557470  10/11/2022        PR       F          69        1         2.0
# 557472  25/06/2022        SC       M          27        1         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 6                1       1.0         5.0       2.0         1.0
# ...

# %%
df_S22.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  109487.000000  109487.000000  101569.000000  109487.000000
# mean       48.677788       2.201001       2.104491       1.402769
# std        32.034739       2.586896       1.001092       0.490457
# min         0.000000       1.000000       1.000000       1.000000
# 25%        10.000000       1.000000       2.000000       1.000000
# 50%        59.000000       1.000000       2.000000       1.000000
# 75%        76.000000       1.000000       2.000000       2.000000
# max       123.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  108460.000000  108498.000000  106357.000000  109473.000000
# mean        1.015656       4.102509       1.352116       1.481443
# std         0.171322       1.066815       1.120446       1.104795
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_S22.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  109487.000000  109487.000000  101569.000000  109487.000000
# mean       48.677788       2.201001       2.104491       1.402769
# std        32.034739       2.586896       1.001092       0.490457
# min         0.000000       1.000000       1.000000       1.000000
# 25%        10.000000       1.000000       2.000000       1.000000
# 50%        59.000000       1.000000       2.000000       1.000000
# 75%        76.000000       1.000000       2.000000       2.000000
# max       123.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  108460.000000  108498.000000  106357.000000  109473.000000
# mean        1.015656       4.102509       1.352116       1.481443
# std         0.171322       1.066815       1.120446       1.104795
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df_S22["CS_SEXO"].value_counts()
# Out:
# M    55139
# F    54346
# I        2
# Name: CS_SEXO, dtype: int64

# %%
df_S22["CS_RACA"].value_counts()
# Out:
# 1    84462
# 9    12559
# 4     8623
# 2     3017
# 3      584
# 5      242
# Name: CS_RACA, dtype: int64

# %%
df_S22["CLASSI_FIN"].value_counts()
# Out:
# 4.0    47045
# 5.0    45680
# 2.0    11973
# 1.0     3406
# 3.0      394
# Name: CLASSI_FIN, dtype: int64

# %%
df_S22["EVOLUCAO"].value_counts()
# Out:
# 1.0    85105
# 2.0    16034
# 3.0     3388
# 9.0     1830
# Name: EVOLUCAO, dtype: int64

# %%
df_S22["VACINA_COV"].value_counts()
# Out:
# 1.0    70054
# 2.0    37521
# 9.0     1898
# Name: VACINA_COV, dtype: int64

# %%
df_S22["HOSPITAL"].value_counts()
# Out:
# 1.0    106951
# 2.0      1482
# 9.0        27
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S22, x="NU_IDADE_N", color="red").set(title='Idade sul 2022');

# %%
sns.countplot(data=df_S22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2022");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2022)

# %%
df_CO22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "MS")| (tabela_2022["SG_UF_NOT"] == "MT") | (tabela_2022["SG_UF_NOT"] == "GO")]

# %%
df_CO22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 1       03/01/2022        MS       F          37        4         2.0
# 2       04/01/2022        GO       F          33        4         2.0
# 3       04/01/2022        GO       M          76        4         1.0
# 5       02/01/2022        MT       M          21        4         2.0
# 12      06/01/2022        MS       M           1        1         2.0
# ...            ...       ...     ...         ...      ...         ...
# 557385  20/01/2022        GO       F          85        4         2.0
# 557401  27/10/2022        MS       M          72        4         2.0
# 557440  15/12/2022        MS       M          24        4         2.0
# 557450  18/12/2022        GO       M          93        9         2.0
# 557459  11/12/2022        MS       M          10        4         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 1                2       1.0         1.0       1.0         1.0
# ...

# %%
df_CO22.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  30066.000000  30066.000000  27623.000000  30066.000000  29830.000000
# mean      48.702654      3.707743      2.205843      1.443158      1.027590
# std       31.276067      2.357454      1.304648      0.496767      0.271595
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%       12.000000      1.000000      2.000000      1.000000      1.000000
# 50%       58.000000      4.000000      2.000000      1.000000      1.000000
# 75%       76.000000      4.000000      2.000000      2.000000      1.000000
# max      117.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  29624.000000  29132.000000  30061.000000
# mean       4.190555      1.276603      1.547886
# std        1.106571      0.702031      1.146813
# min        1.000000      1.000000      1.000000
# ...

# %%
df_CO22["CS_SEXO"].value_counts()
# Out:
# M    15683
# F    14383
# Name: CS_SEXO, dtype: int64

# %%
df_CO22["CS_RACA"].value_counts()
# Out:
# 4    16574
# 1     8346
# 9     3613
# 2      895
# 3      331
# 5      307
# Name: CS_RACA, dtype: int64

# %%
df_CO22["CLASSI_FIN"].value_counts()
# Out:
# 5.0    15088
# 4.0    10295
# 2.0     2788
# 1.0     1207
# 3.0      246
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO22["EVOLUCAO"].value_counts()
# Out:
# 1.0    22608
# 2.0     5770
# 3.0      624
# 9.0      130
# Name: EVOLUCAO, dtype: int64

# %%
df_CO22["VACINA_COV"].value_counts()
# Out:
# 1.0    17602
# 2.0    11886
# 9.0      573
# Name: VACINA_COV, dtype: int64

# %%
df_CO22["HOSPITAL"].value_counts()
# Out:
# 1.0    29182
# 2.0      623
# 9.0       25
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO22, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2022');

# %%
sns.countplot(data=df_CO22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2022");

# %% [markdown]
# #### Analise descritiva Norte (2022)

# %%
df_N22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "TO")| (tabela_2022["SG_UF_NOT"] == "PA") | (tabela_2022["SG_UF_NOT"] == "AP")  | (tabela_2022["SG_UF_NOT"] == "RR") | (tabela_2022["SG_UF_NOT"] == "AM") | (tabela_2022["SG_UF_NOT"] == "AC") | (tabela_2022["SG_UF_NOT"] == "RO")]

# %%
df_N22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 18      10/01/2022        RO       M          69        1         2.0
# 26      05/01/2022        PA       M          60        4         2.0
# 34      07/01/2022        TO       M          77        2         2.0
# 41      19/01/2022        AC       M          51        4         2.0
# 48      18/01/2022        PA       M          56        4         9.0
# ...            ...       ...     ...         ...      ...         ...
# 557414  19/12/2022        PA       F          78        4         2.0
# 557425  10/07/2022        RO       F           2        4         NaN
# 557426  02/01/2022        RO       F          86        4         2.0
# 557448  19/02/2022        PA       M           8        4         2.0
# 557474  26/07/2022        RO       F           1        4         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 18               1       1.0         4.0       1.0         1.0
# ...

# %%
df_N22.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  24282.000000  24282.000000  20655.000000  24282.000000  22648.000000
# mean      44.298369      3.945062      2.132026      1.563916      1.058548
# std       31.264228      1.403085      1.182671      0.495908      0.431483
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        9.000000      4.000000      2.000000      1.000000      1.000000
# 50%       49.000000      4.000000      2.000000      2.000000      1.000000
# 75%       72.000000      4.000000      2.000000      2.000000      1.000000
# max      122.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  22761.000000  21031.000000  24271.000000
# mean       4.331488      1.522372      1.709077
# std        0.843093      1.431312      1.389210
# min        1.000000      1.000000      1.000000
# ...

# %%
df_N22["CS_SEXO"].value_counts()
# Out:
# M    12819
# F    11459
# I        4
# Name: CS_SEXO, dtype: int64

# %%
df_N22["CS_RACA"].value_counts()
# Out:
# 4    20000
# 1     1990
# 9     1085
# 2      544
# 5      481
# 3      182
# Name: CS_RACA, dtype: int64

# %%
df_N22["CLASSI_FIN"].value_counts()
# Out:
# 5.0    11081
# 4.0     9884
# 2.0     1158
# 3.0      347
# 1.0      291
# Name: CLASSI_FIN, dtype: int64

# %%
df_N22["EVOLUCAO"].value_counts()
# Out:
# 1.0    15460
# 2.0     4014
# 3.0      914
# 9.0      643
# Name: EVOLUCAO, dtype: int64

# %%
df_N22["VACINA_COV"].value_counts()
# Out:
# 1.0    12290
# 2.0    11234
# 9.0      747
# Name: VACINA_COV, dtype: int64

# %%
df_N22["HOSPITAL"].value_counts()
# Out:
# 1.0    21693
# 2.0      902
# 9.0       53
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N22, x="NU_IDADE_N", color="blue").set(title='Idade norte 2022');

# %%
sns.countplot(data=df_N22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2022");

# %% [markdown]
# #### Análise Descritiva Nordeste (2022)

# %%
df_NE22 = tabela_2022.loc[(tabela_2022["SG_UF_NOT"] == "AL")| (tabela_2022["SG_UF_NOT"] == "BA") | (tabela_2022["SG_UF_NOT"] == "CE") | (tabela_2022["SG_UF_NOT"] == "MA") | (tabela_2022["SG_UF_NOT"] == "PB") | (tabela_2022["SG_UF_NOT"] == "PE") | (tabela_2022["SG_UF_NOT"] == "PI") | (tabela_2022["SG_UF_NOT"] == "RN") | (tabela_2022["SG_UF_NOT"] == "SE")]

# %%
df_NE22
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 8       06/01/2022        BA       M          83        9         9.0
# 15      08/01/2022        PB       M           2        4         2.0
# 24      16/01/2022        CE       F          47        1         2.0
# 29      12/01/2022        RN       M          79        4         2.0
# 31      17/01/2022        CE       F          49        4         9.0
# ...            ...       ...     ...         ...      ...         ...
# 557457  20/11/2022        BA       M          61        2         9.0
# 557458  17/11/2022        SE       F           1        9         2.0
# 557461  19/11/2022        PE       F          91        9         NaN
# 557471  25/11/2022        PI       F          87        4         2.0
# 557473  26/11/2022        PE       M          73        9         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 8                2       1.0         4.0       2.0         1.0
# ...

# %%
df_NE22.describe()
# Out:
#           NU_IDADE_N        CS_RACA    NOSOCOMIAL     FATOR_RISC  \
# count  104719.000000  104719.000000  76970.000000  104719.000000
# mean       45.347139       4.695280      2.440639       1.530248
# std        32.930805       2.404263      1.806714       0.499087
# min         0.000000       1.000000      1.000000       1.000000
# 25%         7.000000       4.000000      2.000000       1.000000
# 50%        52.000000       4.000000      2.000000       2.000000
# 75%        76.000000       4.000000      2.000000       2.000000
# max       136.000000       9.000000      9.000000       2.000000
#
#            HOSPITAL    CLASSI_FIN      EVOLUCAO     VACINA_COV
# count  94288.000000  83934.000000  78971.000000  103903.000000
# mean       1.065682      4.257476      1.763052       1.765406
# std        0.456797      0.866334      1.895230       1.619312
# min        1.000000      1.000000      1.000000       1.000000
# 25%        1.000000      4.000000      1.000000       1.000000
# ...

# %%
df_NE22["CS_SEXO"].value_counts()
# Out:
# M    52921
# F    51741
# I       57
# Name: CS_SEXO, dtype: int64

# %%
df_NE22["CS_RACA"].value_counts()
# Out:
# 4    68281
# 9    22046
# 1    10108
# 2     3179
# 3      922
# 5      183
# Name: CS_RACA, dtype: int64

# %%
df_NE22["CLASSI_FIN"].value_counts()
# Out:
# 4.0    41296
# 5.0    35782
# 2.0     3339
# 1.0     1988
# 3.0     1529
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE22["EVOLUCAO"].value_counts()
# Out:
# 1.0    54615
# 2.0    16677
# 9.0     4704
# 3.0     2975
# Name: EVOLUCAO, dtype: int64

# %%
df_NE22["VACINA_COV"].value_counts()
# Out:
# 1.0    56099
# 2.0    43272
# 9.0     4532
# Name: VACINA_COV, dtype: int64

# %%
df_NE22["HOSPITAL"].value_counts()
# Out:
# 1.0    89831
# 2.0     4209
# 9.0      248
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE22, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2022');

# %%
sns.countplot(data=df_NE22, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2022");

# %% [markdown]
# ### Descritivas (2023)

# %% [markdown]
# #### Análise Descritiva Sudeste (2023)

# %%
df_SE23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "ES")| (tabela_2023["SG_UF_NOT"] == "RJ") | (tabela_2023["SG_UF_NOT"] == "SP") | (tabela_2023["SG_UF_NOT"] == "MG")]

# %%
df_SE23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 2        24/2/2023        RJ       M           8      4.0         2.0
# 4         4/2/2023        SP       F          18      1.0         NaN
# 6        16/2/2023        SP       F          20      4.0         2.0
# 7        25/2/2023        SP       M           8      1.0         NaN
# 8         8/3/2023        SP       M           5      4.0         2.0
# ...            ...       ...     ...         ...      ...         ...
# 278505   11/9/2023        MG       M           3      4.0         2.0
# 278507   30/9/2023        SP       M          76      4.0         2.0
# 278508   8/10/2023        SP       M           1      4.0         2.0
# 278510   1/12/2023        MG       F          91      1.0         1.0
# 278512  27/12/2023        MG       M           1      1.0         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 2              1.0       1.0         2.0       1.0         1.0
# ...

# %%
df_SE23.describe()
# Out:
#           NU_IDADE_N        CS_RACA     NOSOCOMIAL     FATOR_RISC  \
# count  127358.000000  127358.000000  112561.000000  127357.000000
# mean       36.164473       3.223567       2.317925       1.512724
# std        33.909115       2.760485       1.530421       0.499840
# min        -3.000000       1.000000       1.000000       1.000000
# 25%         4.000000       1.000000       2.000000       1.000000
# 50%        21.000000       2.000000       2.000000       2.000000
# 75%        71.000000       4.000000       2.000000       2.000000
# max       123.000000       9.000000       9.000000       2.000000
#
#             HOSPITAL     CLASSI_FIN       EVOLUCAO     VACINA_COV
# count  125683.000000  124024.000000  119617.000000  127334.000000
# mean        1.031794       3.808811       1.332846       1.540476
# std         0.344350       1.056786       1.225707       1.078077
# min         0.000000       1.000000       1.000000       1.000000
# ...

# %%
df_SE23["CS_SEXO"].value_counts()
# Out:
# M    64980
# F    62373
# I        5
# Name: CS_SEXO, dtype: int64

# %%
df_SE23["CS_RACA"].value_counts()
# Out:
# 1.0    60672
# 4.0    40733
# 9.0    19093
# 2.0     5680
# 3.0     1077
# 5.0      103
# Name: CS_RACA, dtype: int64

# %%
df_SE23["CLASSI_FIN"].value_counts()
# Out:
# 4.0    73154
# 5.0    27124
# 2.0    16188
# 1.0     5451
# 3.0     2107
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE23["EVOLUCAO"].value_counts()
# Out:
# 1.0    101208
# 2.0     12766
# 3.0      3016
# 9.0      2627
# Name: EVOLUCAO, dtype: int64

# %%
df_SE23["VACINA_COV"].value_counts()
# Out:
# 1.0    73059
# 2.0    52197
# 9.0     2078
# Name: VACINA_COV, dtype: int64

# %%
df_SE23["HOSPITAL"].value_counts()
# Out:
# 1.0    123064
# 2.0      2421
# 9.0       197
# 0.0         1
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE23, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2023');

# %%
sns.countplot(data=df_SE23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2023");

# %% [markdown]
# #### Análise Descritiva Sul(2023)

# %%
df_S23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "SC")| (tabela_2023["SG_UF_NOT"] == "RS") | (tabela_2023["SG_UF_NOT"] == "PR")]

# %%
df_S23
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0       23/1/2023        RS       M          81      1.0         2.0
# 1       13/2/2023        SC       M          76      1.0         2.0
# 5       25/2/2023        PR       M           2      4.0         2.0
# 10       7/1/2023        PR       F          58      2.0         2.0
# 12      17/1/2023        SC       M          85      1.0         2.0
# ...           ...       ...     ...         ...      ...         ...
# 278485   2/6/2023        PR       M          67      1.0         NaN
# 278489  19/6/2023        RS       M          80      1.0         2.0
# 278490  11/6/2023        PR       M          76      9.0         2.0
# 278493  16/7/2023        RS       F          65      1.0         2.0
# 278497  22/5/2023        PR       F          67      4.0         1.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0              1.0       1.0         5.0       3.0         1.0
# ...

# %%
df_S23.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  55421.000000  55421.000000  50621.000000  55421.000000  54771.000000
# mean      34.825842      2.221144      2.095059      1.497122      1.007248
# std       33.286225      2.582908      0.963935      0.499996      0.139519
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        4.000000      1.000000      2.000000      1.000000      1.000000
# 50%       16.000000      1.000000      2.000000      1.000000      1.000000
# 75%       69.000000      1.000000      2.000000      2.000000      1.000000
# max      113.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  54710.000000  53646.000000  55416.000000
# mean       3.504076      1.216922      1.530551
# std        1.190761      0.816831      0.885814
# min        1.000000      1.000000      1.000000
# ...

# %%
df_S23["CS_SEXO"].value_counts()
# Out:
# M    28523
# F    26897
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_S23["CS_RACA"].value_counts()
# Out:
# 1.0    42373
# 9.0     6304
# 4.0     4924
# 2.0     1441
# 3.0      242
# 5.0      137
# Name: CS_RACA, dtype: int64

# %%
df_S23["CLASSI_FIN"].value_counts()
# Out:
# 4.0    27730
# 2.0    14080
# 5.0     9690
# 1.0     2726
# 3.0      484
# Name: CLASSI_FIN, dtype: int64

# %%
df_S23["EVOLUCAO"].value_counts()
# Out:
# 1.0    46739
# 2.0     4637
# 3.0     1860
# 9.0      410
# Name: EVOLUCAO, dtype: int64

# %%
df_S23["VACINA_COV"].value_counts()
# Out:
# 1.0    29725
# 2.0    25161
# 9.0      530
# Name: VACINA_COV, dtype: int64

# %%
df_S23["HOSPITAL"].value_counts()
# Out:
# 1.0    54458
# 2.0      301
# 9.0       12
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S23, x="NU_IDADE_N", color="red").set(title='Idade sul 2023');

# %%
sns.countplot(data=df_S23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2023");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2023)

# %%
df_CO23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "MS")| (tabela_2023["SG_UF_NOT"] == "MT") | (tabela_2023["SG_UF_NOT"] == "GO")]

# %%
df_CO23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 19       17/2/2023        GO       M           1      9.0         2.0
# 30        5/4/2023        MS       F           6      4.0         2.0
# 46       25/1/2023        GO       M           8      4.0         2.0
# 56       17/2/2023        MS       M           4      1.0         9.0
# 61        2/1/2023        GO       F          38      9.0         2.0
# ...            ...       ...     ...         ...      ...         ...
# 278469   28/3/2023        MS       F          13      4.0         2.0
# 278476   29/4/2023        GO       F           3      4.0         2.0
# 278477   28/4/2023        GO       F          20      9.0         9.0
# 278480    5/5/2023        MS       F           1      4.0         2.0
# 278511  23/12/2023        GO       F           5      4.0         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 19             2.0       1.0         4.0       1.0         2.0
# ...

# %%
df_CO23.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  16499.000000  16499.000000  15505.000000  16499.000000  16380.000000
# mean      31.324868      3.677859      2.144147      1.552337      1.031441
# std       31.799639      2.162044      1.129708      0.497268      0.285901
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      1.000000      2.000000      1.000000      1.000000
# 50%       11.000000      4.000000      2.000000      2.000000      1.000000
# 75%       63.000000      4.000000      2.000000      2.000000      1.000000
# max      114.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  16268.000000  15671.000000  16497.000000
# mean       3.465023      1.200179      1.631084
# std        1.257451      0.640329      1.094049
# min        1.000000      1.000000      1.000000
# ...

# %%
df_CO23["CS_SEXO"].value_counts()
# Out:
# M    8528
# F    7970
# I       1
# Name: CS_SEXO, dtype: int64

# %%
df_CO23["CS_RACA"].value_counts()
# Out:
# 4.0    9965
# 1.0    4137
# 9.0    1579
# 2.0     435
# 5.0     227
# 3.0     156
# Name: CS_RACA, dtype: int64

# %%
df_CO23["CLASSI_FIN"].value_counts()
# Out:
# 4.0    7915
# 2.0    3720
# 5.0    3043
# 1.0    1358
# 3.0     232
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO23["EVOLUCAO"].value_counts()
# Out:
# 1.0    13421
# 2.0     1669
# 3.0      530
# 9.0       51
# Name: EVOLUCAO, dtype: int64

# %%
df_CO23["VACINA_COV"].value_counts()
# Out:
# 2.0    8139
# 1.0    8074
# 9.0     284
# Name: VACINA_COV, dtype: int64

# %%
df_CO23["HOSPITAL"].value_counts()
# Out:
# 1.0    15970
# 2.0      395
# 9.0       15
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO23, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2023');

# %%
sns.countplot(data=df_CO23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2023");

# %% [markdown]
# #### Analise descritiva Norte (2023)

# %%
df_N23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "TO")| (tabela_2023["SG_UF_NOT"] == "PA") | (tabela_2023["SG_UF_NOT"] == "AP")  | (tabela_2023["SG_UF_NOT"] == "RR") | (tabela_2023["SG_UF_NOT"] == "AM") | (tabela_2023["SG_UF_NOT"] == "AC") | (tabela_2023["SG_UF_NOT"] == "RO")]

# %%
df_N23
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 17       5/2/2023        AM       M          60      5.0         NaN
# 74      25/1/2023        AC       F          78      4.0         2.0
# 88       8/4/2023        AP       F           1      1.0         2.0
# 98       5/4/2023        AM       M          78      4.0         2.0
# 110      1/5/2023        AM       M           5      9.0         9.0
# ...           ...       ...     ...         ...      ...         ...
# 278458   1/2/2023        RO       M          61      4.0         2.0
# 278463  13/2/2023        AM       M          26      4.0         1.0
# 278470  18/3/2023        RO       F          28      4.0         NaN
# 278481  29/4/2023        AP       F           7      4.0         2.0
# 278506   5/9/2023        AM       M           6      9.0         NaN
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 17             2.0       1.0         4.0       1.0         1.0
# ...

# %%
df_N23.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  17020.000000  17020.000000  14374.000000  17020.000000  15743.000000
# mean      25.084665      4.119976      2.071101      1.677497      1.052658
# std       30.129968      1.569417      0.872651      0.467448      0.426041
# min       -5.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      4.000000      2.000000      1.000000      1.000000
# 50%        7.000000      4.000000      2.000000      2.000000      1.000000
# 75%       50.000000      4.000000      2.000000      2.000000      1.000000
# max      112.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  15920.000000  15455.000000  17013.000000
# mean       3.500503      1.348107      1.720743
# std        1.128527      1.223269      1.094851
# min        1.000000      1.000000      1.000000
# ...

# %%
df_N23["CS_SEXO"].value_counts()
# Out:
# M    9083
# F    7933
# I       4
# Name: CS_SEXO, dtype: int64

# %%
df_N23["CS_RACA"].value_counts()
# Out:
# 4.0    13638
# 1.0     1313
# 9.0     1154
# 5.0      660
# 2.0      194
# 3.0       61
# Name: CS_RACA, dtype: int64

# %%
df_N23["EVOLUCAO"].value_counts()
# Out:
# 1.0    12996
# 2.0     1506
# 3.0      625
# 9.0      328
# Name: EVOLUCAO, dtype: int64

# %%
df_N23["CLASSI_FIN"].value_counts()
# Out:
# 4.0    9262
# 2.0    3348
# 5.0    1970
# 1.0     943
# 3.0     397
# Name: CLASSI_FIN, dtype: int64

# %%
df_N23["VACINA_COV"].value_counts()
# Out:
# 2.0    9838
# 1.0    6872
# 9.0     303
# Name: VACINA_COV, dtype: int64

# %%
df_N23["HOSPITAL"].value_counts()
# Out:
# 1.0    15173
# 2.0      533
# 9.0       37
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N23, x="NU_IDADE_N", color="blue").set(title='Idade norte 2023');

# %%
sns.countplot(data=df_N23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2023");

# %% [markdown]
# #### Analise descritiva Nordeste (2023)

# %%
df_NE23 = tabela_2023.loc[(tabela_2023["SG_UF_NOT"] == "AL")| (tabela_2023["SG_UF_NOT"] == "BA") | (tabela_2023["SG_UF_NOT"] == "CE") | (tabela_2023["SG_UF_NOT"] == "MA") | (tabela_2023["SG_UF_NOT"] == "PB") | (tabela_2023["SG_UF_NOT"] == "PE") | (tabela_2023["SG_UF_NOT"] == "PI") | (tabela_2023["SG_UF_NOT"] == "RN") | (tabela_2023["SG_UF_NOT"] == "SE")]

# %%
df_NE23
# Out:
#         DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 3        26/2/2023        CE       M           1      4.0         NaN
# 13       17/1/2023        PI       M           6      4.0         NaN
# 18        9/2/2023        PE       F          86      4.0         9.0
# 20       12/1/2023        CE       M           7      4.0         2.0
# 25       15/3/2023        CE       M           3      4.0         2.0
# ...            ...       ...     ...         ...      ...         ...
# 278496   14/7/2023        CE       M           1      4.0         NaN
# 278500   10/3/2023        CE       M           8      4.0         2.0
# 278501   13/8/2023        SE       M           3      9.0         2.0
# 278509  13/11/2023        BA       M          87      4.0         NaN
# 278513    6/7/2023        PE       M           1      1.0         2.0
#
#         FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 3              2.0       1.0         4.0       1.0         1.0
# ...

# %%
df_NE23.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  50569.000000  50569.000000  41570.000000  50569.000000  46699.000000
# mean      24.501315      4.600229      2.433365      1.672487      1.058738
# std       30.951918      2.296530      1.764408      0.469311      0.543257
# min       -5.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      4.000000      2.000000      1.000000      1.000000
# 50%        7.000000      4.000000      2.000000      2.000000      1.000000
# 75%       50.000000      4.000000      2.000000      2.000000      1.000000
# max      121.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  46310.000000  44485.000000  50548.000000
# mean       3.582704      1.650107      1.775916
# std        1.097926      1.947973      1.360182
# min        1.000000      1.000000      1.000000
# ...

# %%
df_NE23["CS_SEXO"].value_counts()
# Out:
# M    26658
# F    23902
# I        9
# Name: CS_SEXO, dtype: int64

# %%
df_NE23["CS_RACA"].value_counts()
# Out:
# 4.0    34611
# 9.0     9460
# 1.0     4773
# 2.0     1245
# 3.0      309
# 5.0      171
# Name: CS_RACA, dtype: int64

# %%
df_NE23["CLASSI_FIN"].value_counts()
# Out:
# 4.0    28134
# 2.0     9261
# 5.0     6297
# 1.0     2241
# 3.0      377
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE23["EVOLUCAO"].value_counts()
# Out:
# 1.0    36483
# 2.0     3776
# 9.0     2782
# 3.0     1444
# Name: EVOLUCAO, dtype: int64

# %%
df_NE23["VACINA_COV"].value_counts()
# Out:
# 2.0    27117
# 1.0    21918
# 9.0     1513
# Name: VACINA_COV, dtype: int64

# %%
df_NE23["HOSPITAL"].value_counts()
# Out:
# 1.0    45356
# 2.0     1143
# 9.0      200
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE23, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2023');

# %%
sns.countplot(data=df_NE23, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2023");

# %% [markdown]
# ### Descritivas (2024)

# %% [markdown]
# #### Análise Descritiva Sudeste (2024)

# %%
df_SE24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "ES")| (tabela_2024["SG_UF_NOT"] == "RJ") | (tabela_2024["SG_UF_NOT"] == "SP") | (tabela_2024["SG_UF_NOT"] == "MG")]

# %%
df_SE24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 9        1/1/2024        SP       F          77        1         NaN
# 14     31/12/2023        SP       F          78        9         2.0
# 17       2/1/2024        SP       F           1        4         2.0
# 21       3/1/2024        RJ       F          73        2         2.0
# 22       1/1/2024        SP       M          68        1         2.0
# ...           ...       ...     ...         ...      ...         ...
# 56112    1/4/2024        SP       M           4        9         2.0
# 56113   13/3/2024        MG       F          85        4         2.0
# 56114    1/4/2024        MG       F           1        9         2.0
# 56115    9/4/2024        SP       F           5        4         2.0
# 56117    7/4/2024        SP       M          63        4         9.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 9               1       1.0         5.0       1.0         1.0
# ...

# %%
df_SE24.describe()
# Out:
#          NU_IDADE_N       CS_RACA    NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  25062.000000  25062.000000  21518.000000  25062.000000  24363.000000
# mean      39.675884      3.254529      2.260712      1.488189      1.048188
# std       34.154709      2.809753      1.445376      0.499870      0.454724
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        5.000000      1.000000      2.000000      1.000000      1.000000
# 50%       38.000000      2.000000      2.000000      1.000000      1.000000
# 75%       74.000000      4.000000      2.000000      2.000000      1.000000
# max      108.000000      9.000000      9.000000      2.000000      9.000000
#
#          CLASSI_FIN      EVOLUCAO    VACINA_COV
# count  21371.000000  17793.000000  25048.000000
# mean       3.782930      1.518968      1.613502
# std        1.229264      1.614031      1.224889
# min        1.000000      1.000000      1.000000
# ...

# %%
df_SE24["CS_SEXO"].value_counts()
# Out:
# M    12638
# F    12423
# I        1
# Name: CS_SEXO, dtype: int64

# %%
df_SE24["CS_RACA"].value_counts()
# Out:
# 1    12008
# 4     7740
# 9     3957
# 2     1141
# 3      189
# 5       27
# Name: CS_RACA, dtype: int64

# %%
df_SE24["CLASSI_FIN"].value_counts()
# Out:
# 4.0    9574
# 5.0    6668
# 2.0    3210
# 1.0    1484
# 3.0     435
# Name: CLASSI_FIN, dtype: int64

# %%
df_SE24["EVOLUCAO"].value_counts()
# Out:
# 1.0    14204
# 2.0     2318
# 9.0      729
# 3.0      542
# Name: EVOLUCAO, dtype: int64

# %%
df_SE24["VACINA_COV"].value_counts()
# Out:
# 1.0    13636
# 2.0    10847
# 9.0      565
# Name: VACINA_COV, dtype: int64

# %%
df_SE24["HOSPITAL"].value_counts()
# Out:
# 1.0    23679
# 2.0      614
# 9.0       70
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_SE24, x="NU_IDADE_N", color="purple").set(title='Idade sudeste 2024');

# %%
sns.countplot(data=df_SE24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sudeste 2024");

# %% [markdown]
# #### Análise Descritiva Sul(2024)

# %%
df_S24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "SC")| (tabela_2024["SG_UF_NOT"] == "RS") | (tabela_2024["SG_UF_NOT"] == "PR")]

# %%
df_S24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 1        1/1/2024        PR       F          88        1         2.0
# 2      31/12/2023        PR       M          26        1         2.0
# 4        3/1/2024        PR       M           2        1         2.0
# 5      31/12/2023        SC       M          76        1         2.0
# 6        3/1/2024        SC       M          77        1         NaN
# ...           ...       ...     ...         ...      ...         ...
# 56107   28/3/2024        SC       F          89        1         2.0
# 56108    4/4/2024        SC       F           4        1         2.0
# 56110    7/4/2024        PR       M           1        1         2.0
# 56119   19/3/2024        PR       F          76        1         2.0
# 56120    5/4/2024        PR       M          76        1         2.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 1               1       1.0         4.0       2.0         1.0
# ...

# %%
df_S24.describe()
# Out:
#          NU_IDADE_N       CS_RACA   NOSOCOMIAL    FATOR_RISC      HOSPITAL  \
# count  10615.000000  10615.000000  9297.000000  10615.000000  10305.000000
# mean      42.115214      1.923410     2.093363      1.454640      1.012906
# std       33.672980      2.233934     1.035668      0.497962      0.185688
# min        0.000000      1.000000     1.000000      1.000000      1.000000
# 25%        6.000000      1.000000     2.000000      1.000000      1.000000
# 50%       47.000000      1.000000     2.000000      1.000000      1.000000
# 75%       74.000000      1.000000     2.000000      2.000000      1.000000
# max      113.000000      9.000000     9.000000      2.000000      9.000000
#
#         CLASSI_FIN     EVOLUCAO    VACINA_COV
# count  8952.000000  7221.000000  10614.000000
# mean      3.692918     1.329179      1.574147
# std       1.295594     1.115153      1.080704
# min       1.000000     1.000000      1.000000
# 25%       2.000000     1.000000      1.000000
# ...

# %%
df_S24["CS_SEXO"].value_counts()
# Out:
# M    5414
# F    5200
# I       1
# Name: CS_SEXO, dtype: int64

# %%
df_S24["CS_RACA"].value_counts()
# Out:
# 1    8526
# 4     900
# 9     830
# 2     300
# 3      37
# 5      22
# Name: CS_RACA, dtype: int64

# %%
df_S24["CLASSI_FIN"].value_counts()
# Out:
# 4.0    3887
# 5.0    2700
# 2.0    1532
# 1.0     776
# 3.0      57
# Name: CLASSI_FIN, dtype: int64

# %%
df_S24["EVOLUCAO"].value_counts()
# Out:
# 1.0    5974
# 2.0     849
# 3.0     276
# 9.0     122
# Name: EVOLUCAO, dtype: int64

# %%
df_S24["VACINA_COV"].value_counts()
# Out:
# 1.0    5745
# 2.0    4694
# 9.0     175
# Name: VACINA_COV, dtype: int64

# %%
df_S24["HOSPITAL"].value_counts()
# Out:
# 1.0    10200
# 2.0      101
# 9.0        4
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_S24, x="NU_IDADE_N", color="red").set(title='Idade sul 2024');

# %%
sns.countplot(data=df_S24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco sul 2024");

# %% [markdown]
# #### Analise descritiva Centro Oeste (2024)

# %%
df_CO24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "MS")| (tabela_2024["SG_UF_NOT"] == "MT") | (tabela_2024["SG_UF_NOT"] == "GO")]

# %%
df_CO24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 19       5/1/2024        GO       F          16        4         2.0
# 26       1/1/2024        MS       F          39        4         2.0
# 53       2/1/2024        MS       F          37        4         2.0
# 72     31/12/2023        MS       F          46        4         2.0
# 75     31/12/2023        GO       F           3        4         2.0
# ...           ...       ...     ...         ...      ...         ...
# 55980    5/4/2024        GO       M           8        4         2.0
# 56040   21/3/2024        MS       M          60        2         2.0
# 56046    1/4/2024        MS       F          34        4         2.0
# 56072   25/3/2024        GO       F          15        4         2.0
# 56116   29/3/2024        GO       M           7        4         2.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 19              2       1.0         4.0       1.0         1.0
# ...

# %%
df_CO24.describe()
# Out:
#         NU_IDADE_N      CS_RACA   NOSOCOMIAL   FATOR_RISC     HOSPITAL  \
# count  3591.000000  3591.000000  3332.000000  3591.000000  3506.000000
# mean     35.647452     3.502367     2.156363     1.517405     1.025956
# std      32.167310     2.112948     1.245290     0.499767     0.270593
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       4.000000     1.000000     2.000000     1.000000     1.000000
# 50%      29.000000     4.000000     2.000000     2.000000     1.000000
# 75%      68.000000     4.000000     2.000000     2.000000     1.000000
# max     112.000000     9.000000     9.000000     2.000000     9.000000
#
#         CLASSI_FIN     EVOLUCAO   VACINA_COV
# count  3284.000000  2633.000000  3591.000000
# mean      3.819428     1.260919     1.810916
# std       1.208650     0.831044     1.632420
# min       1.000000     1.000000     1.000000
# 25%       4.000000     1.000000     1.000000
# 50%       4.000000     1.000000     1.000000
# ...

# %%
df_CO24["CS_SEXO"].value_counts()
# Out:
# F    1826
# M    1765
# Name: CS_SEXO, dtype: int64

# %%
df_CO24["CS_RACA"].value_counts()
# Out:
# 4    2113
# 1    1013
# 9     293
# 2     101
# 3      41
# 5      30
# Name: CS_RACA, dtype: int64

# %%
df_CO24["CLASSI_FIN"].value_counts()
# Out:
# 4.0    1354
# 5.0    1124
# 2.0     671
# 1.0     120
# 3.0      15
# Name: CLASSI_FIN, dtype: int64

# %%
df_CO24["EVOLUCAO"].value_counts()
# Out:
# 1.0    2181
# 2.0     337
# 3.0      95
# 9.0      20
# Name: EVOLUCAO, dtype: int64

# %%
df_CO24["VACINA_COV"].value_counts()
# Out:
# 1.0    1806
# 2.0    1624
# 9.0     161
# Name: VACINA_COV, dtype: int64

# %%
df_CO24["HOSPITAL"].value_counts()
# Out:
# 1.0    3436
# 2.0      67
# 9.0       3
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_CO24, x="NU_IDADE_N", color="green").set(title='Idade centro-oeste 2024');

# %%
sns.countplot(data=df_CO24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco centro-oeste 2024");

# %% [markdown]
# #### Analise descritiva Norte (2024)

# %%
df_N24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "TO")| (tabela_2024["SG_UF_NOT"] == "PA") | (tabela_2024["SG_UF_NOT"] == "AP")  | (tabela_2024["SG_UF_NOT"] == "RR") | (tabela_2024["SG_UF_NOT"] == "AM") | (tabela_2024["SG_UF_NOT"] == "AC") | (tabela_2024["SG_UF_NOT"] == "RO")]

# %%
df_N24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 7        1/1/2024        AM       F          88        4         2.0
# 10     31/12/2023        RO       M          17        4         NaN
# 23     31/12/2023        TO       M           1        4         2.0
# 86       4/1/2024        PA       F          56        4         2.0
# 106      1/1/2024        AM       F           6        4         2.0
# ...           ...       ...     ...         ...      ...         ...
# 56045   30/3/2024        TO       F           6        4         2.0
# 56053    6/4/2024        AC       F           2        5         9.0
# 56059   23/3/2024        AC       M           5        5         2.0
# 56069    5/4/2024        AC       F          92        4         2.0
# 56088   31/3/2024        RR       M           7        1         2.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 7               1       1.0         5.0       3.0         1.0
# ...

# %%
df_N24.describe()
# Out:
#         NU_IDADE_N      CS_RACA   NOSOCOMIAL   FATOR_RISC     HOSPITAL  \
# count  4207.000000  4207.000000  3596.000000  4207.000000  3979.000000
# mean     29.011410     4.009746     2.088432     1.641787     1.046745
# std      31.310372     1.416783     0.981311     0.479532     0.396473
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       3.000000     4.000000     2.000000     1.000000     1.000000
# 50%       9.000000     4.000000     2.000000     2.000000     1.000000
# 75%      60.000000     4.000000     2.000000     2.000000     1.000000
# max     109.000000     9.000000     9.000000     2.000000     9.000000
#
#         CLASSI_FIN     EVOLUCAO   VACINA_COV
# count  3237.000000  2706.000000  4203.000000
# mean      3.724436     1.705469     1.741137
# std       1.137652     1.949289     1.218448
# min       1.000000     1.000000     1.000000
# 25%       4.000000     1.000000     1.000000
# 50%       4.000000     1.000000     2.000000
# ...

# %%
df_N24["CS_SEXO"].value_counts()
# Out:
# M    2275
# F    1932
# Name: CS_SEXO, dtype: int64

# %%
df_N24["CS_RACA"].value_counts()
# Out:
# 4    3419
# 1     325
# 9     202
# 5     168
# 2      69
# 3      24
# Name: CS_RACA, dtype: int64

# %%
df_N24["CLASSI_FIN"].value_counts()
# Out:
# 4.0    1685
# 5.0     760
# 2.0     558
# 1.0     151
# 3.0      83
# Name: CLASSI_FIN, dtype: int64

# %%
df_N24["EVOLUCAO"].value_counts()
# Out:
# 1.0    2127
# 2.0     257
# 9.0     168
# 3.0     154
# Name: EVOLUCAO, dtype: int64

# %%
df_N24["VACINA_COV"].value_counts()
# Out:
# 2.0    2339
# 1.0    1767
# 9.0      97
# Name: VACINA_COV, dtype: int64

# %%
df_N24["HOSPITAL"].value_counts()
# Out:
# 1.0    3849
# 2.0     122
# 9.0       8
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_N24, x="NU_IDADE_N", color="blue").set(title='Idade norte 2024');

# %%
sns.countplot(data=df_N24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco norte 2024");

# %% [markdown]
# #### Análise Descritiva Nordeste (2024)

# %%
df_NE24 = tabela_2024.loc[(tabela_2024["SG_UF_NOT"] == "AL")| (tabela_2024["SG_UF_NOT"] == "BA") | (tabela_2024["SG_UF_NOT"] == "CE") | (tabela_2024["SG_UF_NOT"] == "MA") | (tabela_2024["SG_UF_NOT"] == "PB") | (tabela_2024["SG_UF_NOT"] == "PE") | (tabela_2024["SG_UF_NOT"] == "PI") | (tabela_2024["SG_UF_NOT"] == "RN") | (tabela_2024["SG_UF_NOT"] == "SE")]

# %%
df_NE24
# Out:
#        DT_SIN_PRI SG_UF_NOT CS_SEXO  NU_IDADE_N  CS_RACA  NOSOCOMIAL  \
# 0        1/1/2024        CE       M          80        4         2.0
# 3        2/1/2024        CE       F          69        4         2.0
# 8        1/1/2024        PE       F          41        4         2.0
# 11       1/1/2024        RN       M           9        1         2.0
# 13     31/12/2023        AL       F          39        4         2.0
# ...           ...       ...     ...         ...      ...         ...
# 56087    5/4/2024        MA       F           1        4         2.0
# 56094   12/4/2024        PB       M          77        4         2.0
# 56095   13/3/2024        BA       F          29        4         NaN
# 56101    2/2/2024        PE       M          83        4         NaN
# 56118   15/3/2024        CE       M           1        1         2.0
#
#        FATOR_RISC  HOSPITAL  CLASSI_FIN  EVOLUCAO  VACINA_COV
# 0               2       1.0         NaN       NaN         2.0
# ...

# %%
df_NE24.describe()
# Out:
#          NU_IDADE_N       CS_RACA   NOSOCOMIAL    FATOR_RISC     HOSPITAL  \
# count  10307.000000  10307.000000  8948.000000  10307.000000  9368.000000
# mean      28.638304      4.396333     2.566384      1.600854     1.077178
# std       32.153528      2.154159     1.984560      0.489747     0.598493
# min        0.000000      1.000000     1.000000      1.000000     1.000000
# 25%        3.000000      4.000000     2.000000      1.000000     1.000000
# 50%        9.000000      4.000000     2.000000      2.000000     1.000000
# 75%       61.000000      4.000000     2.000000      2.000000     1.000000
# max      107.000000      9.000000     9.000000      2.000000     9.000000
#
#         CLASSI_FIN     EVOLUCAO    VACINA_COV
# count  7532.000000  6391.000000  10300.000000
# mean      3.453266     1.905805      1.815437
# std       1.306376     2.270836      1.468647
# min       1.000000     1.000000      1.000000
# 25%       2.000000     1.000000      1.000000
# ...

# %%
df_NE24["CS_SEXO"].value_counts()
# Out:
# M    5467
# F    4835
# I       5
# Name: CS_SEXO, dtype: int64

# %%
df_NE24["CS_RACA"].value_counts()
# Out:
# 4    7324
# 9    1559
# 1    1021
# 2     292
# 3      87
# 5      24
# Name: CS_RACA, dtype: int64

# %%
df_NE24["CLASSI_FIN"].value_counts()
# Out:
# 4.0    4290
# 1.0    1182
# 5.0    1145
# 2.0     802
# 3.0     113
# Name: CLASSI_FIN, dtype: int64

# %%
df_NE24["EVOLUCAO"].value_counts()
# Out:
# 1.0    4835
# 2.0     743
# 9.0     570
# 3.0     243
# Name: EVOLUCAO, dtype: int64

# %%
df_NE24["VACINA_COV"].value_counts()
# Out:
# 2.0    5447
# 1.0    4484
# 9.0     369
# Name: VACINA_COV, dtype: int64

# %%
df_NE24["HOSPITAL"].value_counts()
# Out:
# 1.0    8981
# 2.0     339
# 9.0      48
# Name: HOSPITAL, dtype: int64

# %%
sns.histplot(df_NE24, x="NU_IDADE_N", color="orange").set(title='Idade nordeste 2024');

# %%
sns.countplot(data=df_NE24, x="CS_SEXO", hue="FATOR_RISC").set(title="Sexo e fator de risco nordeste 2024");
